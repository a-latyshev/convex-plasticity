# %% [markdown]
# Implementation of 2D elasto-plastic problem using FEniCS-X. The code is based on a [legacy solution](https://comet-fenics.readthedocs.io/en/latest/demo/2D_plasticity/vonMises_plasticity.py.html) for FEniCS 2019.
#
# The program was tested for 0.3.1.0 version of Dolfinx.

# %%
import convex_return_mapping as crm # there is a conflict in the oder of imported modules
import meshio
import numpy as np

import ufl
from dolfinx import fem, io, common
from mpi4py import MPI
from petsc4py import PETSc

import sys
sys.path.append("../")
import fenicsx_support as fs
sys.path.append("../../optimisation")
import plasticity_framework as pf

# %%
if MPI.COMM_WORLD.rank == 0:

    #It works with the msh4 only!!
    msh = meshio.read("thick_cylinder_coarse.msh")

    # Create and save one file for the mesh, and one file for the facets 
    triangle_mesh = fs.create_mesh(msh, "triangle", prune_z=True)
    line_mesh = fs.create_mesh(msh, "line", prune_z=True)
    meshio.write("thick_cylinder.xdmf", triangle_mesh)
    meshio.write("mt.xdmf", line_mesh)
    print(msh)
# Out:
# <meshio mesh object>
#   Number of points: 50
#   Number of cells:
#     line: 2
#     line: 14
#     line: 2
#     line: 11
#     triangle: 69
#   Cell sets: gmsh:bounding_entities
#   Point data: gmsh:dim_tags
#   Cell data: gmsh:physical, gmsh:geometrical

# %%
with io.XDMFFile(MPI.COMM_WORLD, "thick_cylinder.xdmf", "r") as xdmf:
    mesh = xdmf.read_mesh(name="Grid")
    ct = xdmf.read_meshtags(mesh, name="Grid")

mesh.topology.create_connectivity(mesh.topology.dim, mesh.topology.dim - 1)

with io.XDMFFile(MPI.COMM_WORLD, "mt.xdmf", "r") as xdmf:
    ft = xdmf.read_meshtags(mesh, name="Grid")

# %%
# elastic parameters
sig0_dim = 70e3 #[Pa]
Ri_dim = 1.0 #[m]

E = 70e3 / sig0_dim #[-]
nu = 0.3 #[-]
lmbda = E*nu/(1+nu)/(1-2*nu)
mu = fem.Constant(mesh, PETSc.ScalarType(E/2./(1+nu)))

sig0 = 250 / sig0_dim #[-]
Et = E/100.  # tangent modulus
H = E*Et/(E-Et)  # hardening modulus

Re, Ri = 1.3, 1.   # external/internal radius

# %%
deg_u = 2
deg_stress = 2
V = fem.VectorFunctionSpace(mesh, ("CG", deg_u))
We = ufl.VectorElement("Quadrature", mesh.ufl_cell(), degree=deg_stress, dim=4, quad_scheme='default')
W0e = ufl.FiniteElement("Quadrature", mesh.ufl_cell(), degree=deg_stress, quad_scheme='default')

W = fem.FunctionSpace(mesh, We)
W0 = fem.FunctionSpace(mesh, W0e)

# %%
sig = fem.Function(W)
sig_old = fem.Function(W)
p = fem.Function(W0, name="Cumulative_plastic_strain")
p_old = fem.Function(W0)
u = fem.Function(V, name="Total_displacement")
Du = fem.Function(V, name="Current_increment")
v_ = ufl.TrialFunction(V)
u_ = ufl.TestFunction(V)

deps = fem.Function(W, name="deps")

# %%
left_marker = 3
down_marker = 1
left_facets = ft.indices[ft.values == left_marker]
down_facets = ft.indices[ft.values == down_marker]
left_dofs = fem.locate_dofs_topological(V.sub(0), mesh.topology.dim-1, left_facets)
down_dofs = fem.locate_dofs_topological(V.sub(1), mesh.topology.dim-1, down_facets)

bcs = [fem.dirichletbc(PETSc.ScalarType(0), left_dofs, V.sub(0)), fem.dirichletbc(PETSc.ScalarType(0), down_dofs, V.sub(1))]

# %%
ds = ufl.Measure("ds", domain=mesh, subdomain_data=ft)
dx = ufl.Measure(
    "dx",
    domain=mesh,
    metadata={"quadrature_degree": deg_stress, "quadrature_scheme": "default"},
)

# %%
n = ufl.FacetNormal(mesh)
q_lim = float(2/np.sqrt(3)*np.log(Re/Ri)*sig0)
loading = fem.Constant(mesh, PETSc.ScalarType(0.0 * q_lim))

SQRT2 = np.sqrt(2.)

def F_ext(v):
    return -loading * ufl.inner(n, v)*ds(4)

def eps(v):
    e = ufl.sym(ufl.grad(v))
    return ufl.as_tensor([[e[0, 0], e[0, 1], 0],
                          [e[0, 1], e[1, 1], 0],
                          [0, 0, 0]])

def eps_vec(v):
    e = ufl.sym(ufl.grad(v))
    return ufl.as_vector([e[0, 0], e[1, 1], 0, SQRT2 * e[0, 1]])

def as_3D_tensor(X):
    return ufl.as_tensor([[X[0], X[3] / SQRT2, 0],
                          [X[3] / SQRT2, X[1], 0],
                          [0, 0, X[2]]])       
                          
def sigma(eps_el):
    return lmbda*ufl.tr(eps_el)*ufl.Identity(3) + 2*mu*eps_el

def deps_p(deps, old_sig, p, old_p):
    sig_n = as_3D_tensor(old_sig)
    sig_elas = sig_n + sigma(deps)
    s = ufl.dev(sig_elas)
    sig_eq = ufl.sqrt(3/2.*ufl.inner(s, s))
    f_elas = sig_eq - sig0 - H*old_p
    deps_p = ufl.conditional(f_elas > 0, (p - p_old) * (3./2. * s / sig_eq), 0*ufl.Identity(3)) # sig_eq is equal to 0 on the first iteration
    return deps_p

# %%
vonMises = crm.vonMises(sig0, H)
alpha = 0
DruckerPrager = crm.DruckerPrager(sig0, alpha, H)
material = crm.Material(crm.IsotropicElasticity(E, nu), DruckerPrager)
material = crm.Material(crm.IsotropicElasticity(E, nu), vonMises)

n_quadrature_points = len(p.x.array)

N = patch_size = 10 # or batch, or group ?
N_patches = int(n_quadrature_points / patch_size)
residue_size = n_quadrature_points % patch_size

return_mapping = crm.ReturnMapping(material, patch_size, 'ECOS')

p_values = p.x.array[:n_quadrature_points - residue_size].reshape((-1, patch_size))
p_old_values = p_old.x.array[:n_quadrature_points - residue_size].reshape((-1, patch_size))
deps_values = deps.x.array[:4*(n_quadrature_points - residue_size)].reshape((-1, patch_size, 4))
sig_values = sig.x.array[:4*(n_quadrature_points - residue_size)].reshape((-1, patch_size, 4))
sig_old_values = sig_old.x.array[:4*(n_quadrature_points - residue_size)].reshape((-1, patch_size, 4))

if residue_size != 0:
    return_mapping_residue = crm.ReturnMapping(material, residue_size, 'ECOS')
    
    p_values_residue = p.x.array[n_quadrature_points - residue_size:].reshape((1, residue_size))
    p_old_values_residue = p_old.x.array[n_quadrature_points - residue_size:].reshape((1, residue_size))
    deps_values_residue = deps.x.array[4*(n_quadrature_points - residue_size):].reshape((1, residue_size, 4))
    sig_values_residue = sig.x.array[4*(n_quadrature_points - residue_size):].reshape((1, residue_size, 4))
    sig_old_values_residue = sig_old.x.array[4*(n_quadrature_points - residue_size):].reshape((1, residue_size, 4))

# %%
tol = 1.0e-13
scs_params = {'eps': tol, 'eps_abs': tol, 'eps_rel': tol}
ecos_params = {'max_iters': 2500, 'abstol': 1e-13, 'reltol': 1e-13, 'feastol': 1e-13}
conic_solver_params = ecos_params

# %%
# tols dont work: 1-e14, 1e-15
# tols work slowly: 1e-11, 1-e13
# tols work fast: 1e-12
# SCS QN=1e-7 tols=1e-13 : 37 s
# SCS QN=1e-7 tols=1e-12 : 36 s
# SCS QN=1e-8 tols=1e-13 : 53 s
# SCS QN=1e-8 tols=1e-12 : 50 s

# %%
petsc_options_SNES = {
    "snes_type": "vinewtonrsls",
    "snes_linesearch_type": "basic",
    "ksp_type": "preonly",
    "pc_type": "lu",
    "pc_factor_mat_solver_type": "mumps",
    "snes_atol": 1.0e-08,
    "snes_rtol": 1.0e-08,
    "snes_stol": 0.0,
    "snes_max_it": 500,
    "snes_monitor": "",
}

petsc_options_SNESQN = {
    "snes_type": "qn",
    "snes_qn_type": "lbfgs", #lbfgs broyden, badbroyden
    "snes_qn_m": 100,
    "snes_qn_scale_type": "jacobian", #<diagonal,none,scalar,jacobian> 	
    "snes_qn_restart_type": "none", #<powell,periodic,none> 
    "pc_type": "cholesky", # cholesky >> hypre > gamg,sor ; asm, lu, gas - don't work
    "snes_linesearch_type": "basic",
    "ksp_type": "preonly",
    "pc_factor_mat_solver_type": "mumps",
    "snes_atol": 1.0e-08,
    "snes_rtol": 1.0e-08,
    "snes_stol": 0.0,
    "snes_max_it": 500,
    "snes_monitor": "",
    # "snes_monitor_cancel": "",
}

def inside_Newton():
    fs.interpolate_quadrature(eps_vec(Du), deps) # eps_xy * sqrt(2.)!

    for q in range(N_patches):
        return_mapping.deps.value[:] = deps_values[q,:].T
        return_mapping.sig_old.value[:] = sig_old_values[q,:].T
        return_mapping.p_old.value = p_old_values[q,:]
        
        return_mapping.solve(verbose=False, **conic_solver_params)
        sig_values[q,:] = return_mapping.sig.value[:].T
        p_values[q,:] = return_mapping.p.value

    if residue_size != 0: #how to improve ?
        return_mapping_residue.deps.value[:] = deps_values_residue[0,:].T
        return_mapping_residue.sig_old.value[:] = sig_old_values_residue[0,:].T
        return_mapping_residue.p_old.value = p_old_values_residue[0,:]
        
        return_mapping_residue.solve(verbose=False, **conic_solver_params)

        sig_values_residue[0,:] = return_mapping_residue.sig.value[:].T
        p_values_residue[0,:] = return_mapping_residue.p.value

residual = ufl.inner(as_3D_tensor(sig_old) + sigma(eps(Du) - deps_p(eps(Du), sig_old, p, p_old)), eps(u_))*dx - F_ext(u_)
# J = ufl.derivative(ufl.inner(sigma(eps(Du)), eps(u_))*dx, Du, v_) #TODO: check J-formula!
J = ufl.derivative(ufl.inner(sigma(eps(Du) - deps_p(eps(Du), sig_old, p, p_old)), eps(u_))*dx, Du, v_)
snes_problem = pf.SNESProblem(residual, Du, J, bcs, petsc_options=petsc_options_SNESQN, inside_Newton=inside_Newton)

# %%
# Defining a cell containing (Ri, 0) point, where we calculate a value of u
x_point = np.array([[Ri, 0, 0]])
cells, points_on_proc = fs.find_cell_by_point(mesh, x_point)

# %%
Nincr = 20
load_steps = np.linspace(0, 1.1, Nincr+1)[1:]**0.5
results = np.zeros((Nincr+1, 2))

sig.vector.set(0.0)
sig_old.vector.set(0.0)
p.vector.set(0.0)
p_old.vector.set(0.0)
u.vector.set(0.0)

with common.Timer() as timer: 
    for (i, t) in enumerate(load_steps):
        loading.value = t * q_lim

        Du.x.array[:] = 0
        
        if MPI.COMM_WORLD.rank == 0:
            print(f"\n Increment: {str(i+1)}, load = {t * q_lim}")

        snes_problem.solve()

        u.vector.axpy(1, Du.vector) # u = u + 1*Du
        u.x.scatter_forward()

        p_old.x.array[:] = p.x.array        
        sig_old.x.array[:] = sig.x.array

        if len(points_on_proc) > 0:
            results[i+1, :] = (u.eval(points_on_proc, cells)[0], t)
    
    print(f'\nrank#{MPI.COMM_WORLD.rank}: Time = {timer.elapsed()[0]:.3f} (s)')
# Out:
#  Increment: 1, load = 0.0002537449238735671
#   0 SNES Function norm 8.904703628988e-05
#   1 SNES Function norm 9.878568984112e-18
#
#  Increment: 2, load = 0.00035884951272532715
#   0 SNES Function norm 3.688449672543e-05
#   1 SNES Function norm 3.704651133446e-18
#
#  Increment: 3, load = 0.0004394991003117152
#   0 SNES Function norm 2.830246933323e-05
#   1 SNES Function norm 2.968093231272e-18
#
#  Increment: 4, load = 0.0005074898477471342
#   0 SNES Function norm 2.386008646224e-05
#   1 SNES Function norm 2.382879952823e-18
#
#  Increment: 5, load = 0.0005673908987268053
#   0 SNES Function norm 2.102116271839e-05
#   1 SNES Function norm 2.237700156581e-18
#
#  Increment: 6, load = 0.000621545588311601
#   0 SNES Function norm 1.900458299236e-05
#   1 SNES Function norm 2.011067946624e-18
#
#  Increment: 7, load = 0.0006713459650144749
#   0 SNES Function norm 1.747651865616e-05
#   1 SNES Function norm 1.850832286274e-18
#
#  Increment: 8, load = 0.0007176990254506543
#   0 SNES Function norm 1.626676180968e-05
#   1 SNES Function norm 1.801515454040e-18
#
#  Increment: 9, load = 0.0007612347716207013
#   0 SNES Function norm 1.527808348960e-05
#   1 SNES Function norm 1.762249518105e-18
#
#  Increment: 10, load = 0.0008024119041465073
#   0 SNES Function norm 1.445035892359e-05
#   1 SNES Function norm 1.725557792404e-18
#
#  Increment: 11, load = 0.0008415767049459163
#   0 SNES Function norm 1.374420340702e-05
#   1 SNES Function norm 1.576372517935e-18
#
#  Increment: 12, load = 0.0008789982006234304
#   0 SNES Function norm 1.313255712142e-05
#   1 SNES Function norm 1.566948967524e-05
#   2 SNES Function norm 5.478105925221e-06
#   3 SNES Function norm 7.450738200572e-07
#   4 SNES Function norm 5.319737143573e-07
#   5 SNES Function norm 1.286964367482e-07
#   6 SNES Function norm 3.683896016143e-08
#   7 SNES Function norm 3.865350496580e-08
#   8 SNES Function norm 1.890101949345e-07
#   9 SNES Function norm 3.110541796229e-08
#  10 SNES Function norm 2.669846604308e-08
#  11 SNES Function norm 3.928879519404e-08
#  12 SNES Function norm 2.922609979265e-08
#  13 SNES Function norm 3.116113719104e-08
#  14 SNES Function norm 2.362252005593e-08
#  15 SNES Function norm 6.080259205827e-08
#  16 SNES Function norm 2.746892704263e-08
#  17 SNES Function norm 2.127417681549e-08
#  18 SNES Function norm 2.476108673428e-08
#  19 SNES Function norm 2.098383466946e-08
#  20 SNES Function norm 4.023838034057e-08
#  21 SNES Function norm 3.708400580087e-08
#  22 SNES Function norm 1.308488813244e-06
#  23 SNES Function norm 4.033981484165e-08
#  24 SNES Function norm 2.483323420135e-08
#  25 SNES Function norm 3.455601613567e-08
#  26 SNES Function norm 2.902758458967e-08
#  27 SNES Function norm 3.524709015869e-08
#  28 SNES Function norm 2.889173955911e-08
#  29 SNES Function norm 3.424153867514e-08
#  30 SNES Function norm 3.357405294949e-08
#  31 SNES Function norm 6.832508356654e-08
#  32 SNES Function norm 2.776925959106e-08
#  33 SNES Function norm 3.411013649768e-08
#  34 SNES Function norm 2.596511612607e-08
#  35 SNES Function norm 5.788377064105e-08
#  36 SNES Function norm 3.394772119686e-08
#  37 SNES Function norm 5.328699646418e-08
#  38 SNES Function norm 3.152241482131e-08
#  39 SNES Function norm 2.387141035021e-08
#  40 SNES Function norm 2.676112903346e-08
#  41 SNES Function norm 3.134382179082e-08
#  42 SNES Function norm 5.652846508850e-08
#  43 SNES Function norm 2.662274886660e-08
#  44 SNES Function norm 4.090161884666e-08
#  45 SNES Function norm 2.144338409750e-08
#  46 SNES Function norm 2.103510990462e-08
#  47 SNES Function norm 2.910292737302e-08
#  48 SNES Function norm 3.019759563517e-08
#  49 SNES Function norm 9.191759854773e-08
#  50 SNES Function norm 3.506358694797e-08
#  51 SNES Function norm 2.623220190116e-08
#  52 SNES Function norm 2.895501998942e-08
#  53 SNES Function norm 3.877930678169e-08
#  54 SNES Function norm 3.104706762854e-08
#  55 SNES Function norm 3.139090160605e-08
#  56 SNES Function norm 2.519536362053e-08
#  57 SNES Function norm 2.768503786706e-08
#  58 SNES Function norm 2.463051938711e-08
#  59 SNES Function norm 3.128010518053e-08
#  60 SNES Function norm 3.118062904145e-08
#  61 SNES Function norm 2.421474157845e-08
#  62 SNES Function norm 2.225086901558e-08
#  63 SNES Function norm 2.626463637696e-08
#  64 SNES Function norm 2.140035597402e-08
#  65 SNES Function norm 2.565964858085e-08
#  66 SNES Function norm 7.524401312529e-08
#  67 SNES Function norm 1.843780723799e-08
#  68 SNES Function norm 2.472017031822e-08
#  69 SNES Function norm 2.160399635798e-08
#  70 SNES Function norm 7.576313626493e-08
#  71 SNES Function norm 3.534977843656e-08
#  72 SNES Function norm 2.764877089945e-08
#  73 SNES Function norm 2.978367583955e-08
#  74 SNES Function norm 3.027614146885e-08
#  75 SNES Function norm 3.068620959206e-08
#  76 SNES Function norm 5.284940303364e-07
#  77 SNES Function norm 2.936799947772e-08
#  78 SNES Function norm 3.080158874453e-08
#  79 SNES Function norm 3.073528342167e-08
#  80 SNES Function norm 2.999013083077e-08
#  81 SNES Function norm 3.050075110167e-08
#  82 SNES Function norm 2.533365625803e-08
#  83 SNES Function norm 5.283998403561e-08
#  84 SNES Function norm 2.514441234960e-08
#  85 SNES Function norm 2.765802461187e-08
#  86 SNES Function norm 2.970262103829e-08
#  87 SNES Function norm 2.559911715713e-08
#  88 SNES Function norm 2.622691806722e-08
#  89 SNES Function norm 2.647932734544e-08
#  90 SNES Function norm 2.590701445676e-08
#  91 SNES Function norm 3.324171215745e-08
#  92 SNES Function norm 2.409186590947e-08
#  93 SNES Function norm 2.595951143984e-08
#  94 SNES Function norm 2.605039346372e-08
#  95 SNES Function norm 2.829455561668e-08
#  96 SNES Function norm 3.487264395888e-05
#  97 SNES Function norm 2.652509780772e-08
#  98 SNES Function norm 3.163260964608e-08
#  99 SNES Function norm 3.147135207330e-08
# 100 SNES Function norm 2.556117456618e-08
# 101 SNES Function norm 2.959953296987e-08
# 102 SNES Function norm 2.625051425653e-08
# 103 SNES Function norm 2.897372909521e-08
# 104 SNES Function norm 2.788870025313e-08
# 105 SNES Function norm 3.524724916021e-08
# 106 SNES Function norm 2.767628615433e-08
# 107 SNES Function norm 2.852826745147e-08
# 108 SNES Function norm 2.378717313304e-08
# 109 SNES Function norm 6.090030556773e-08
# 110 SNES Function norm 2.682608784214e-08
# 111 SNES Function norm 2.547994730452e-08
# 112 SNES Function norm 2.320838245328e-08
# 113 SNES Function norm 2.652185413435e-08
# 114 SNES Function norm 2.860236310957e-08
# 115 SNES Function norm 2.423932121390e-08
# 116 SNES Function norm 2.483470903331e-08
# 117 SNES Function norm 2.822532273247e-08
# 118 SNES Function norm 2.455643299313e-08
# 119 SNES Function norm 2.676849278020e-08
# 120 SNES Function norm 2.423563905198e-08
# 121 SNES Function norm 2.730658497970e-08
# 122 SNES Function norm 2.553960000407e-08
# 123 SNES Function norm 2.153284698264e-08
# 124 SNES Function norm 2.572061848812e-08
# 125 SNES Function norm 2.776603146385e-08
# 126 SNES Function norm 4.043400565874e-08
# 127 SNES Function norm 2.971587277591e-08
# 128 SNES Function norm 2.992463203615e-08
# 129 SNES Function norm 2.506660504354e-08
# 130 SNES Function norm 2.718280537271e-08
# 131 SNES Function norm 3.308427818438e-08
# 132 SNES Function norm 2.992793062771e-08
# 133 SNES Function norm 3.183418684607e-08
# 134 SNES Function norm 2.503399062231e-08
# 135 SNES Function norm 2.957222612153e-08
# 136 SNES Function norm 2.685331290563e-08
# 137 SNES Function norm 2.771145241430e-08
# 138 SNES Function norm 2.221792872169e-08
# 139 SNES Function norm 2.619553378751e-08
# 140 SNES Function norm 2.624632754029e-08
# 141 SNES Function norm 2.819656671149e-08
# 142 SNES Function norm 2.990370891562e-08
# 143 SNES Function norm 2.274960591171e-08
# 144 SNES Function norm 2.420026294016e-08
# 145 SNES Function norm 2.620519115828e-08
# 146 SNES Function norm 2.852603491643e-08
# 147 SNES Function norm 2.104528197022e-08
# 148 SNES Function norm 3.099782640597e-08
# 149 SNES Function norm 2.681920353122e-08
# 150 SNES Function norm 2.463110756480e-08
# 151 SNES Function norm 2.850513509223e-08
# 152 SNES Function norm 2.722088422174e-08
# 153 SNES Function norm 2.583149628121e-08
# 154 SNES Function norm 2.717323807172e-08
# 155 SNES Function norm 2.683711634159e-08
# 156 SNES Function norm 2.762642685198e-08
# 157 SNES Function norm 2.648873528420e-08
# 158 SNES Function norm 2.751438455527e-08
# 159 SNES Function norm 2.989551605744e-08
# 160 SNES Function norm 3.051456362819e-08
# 161 SNES Function norm 2.888040904072e-08
# 162 SNES Function norm 5.934988576361e-07
# 163 SNES Function norm 2.455280111110e-08
# 164 SNES Function norm 2.881590155671e-08
# 165 SNES Function norm 2.355971875492e-08
# 166 SNES Function norm 2.359296178667e-08
# 167 SNES Function norm 2.634668976348e-08
# 168 SNES Function norm 7.587724720166e-08
# 169 SNES Function norm 2.482439788237e-08
# 170 SNES Function norm 2.663326305517e-08
# 171 SNES Function norm 4.077483440662e-08
# 172 SNES Function norm 2.613859806665e-08
# 173 SNES Function norm 2.756680474607e-08
# 174 SNES Function norm 3.011067914133e-08
# 175 SNES Function norm 2.819173333855e-08
# 176 SNES Function norm 2.411075824375e-08
# 177 SNES Function norm 4.086544182084e-08
# 178 SNES Function norm 3.164357104850e-08
# 179 SNES Function norm 3.364981199714e-08
# 180 SNES Function norm 2.846681336302e-08
# 181 SNES Function norm 2.571005024533e-08
# 182 SNES Function norm 3.005231871406e-08
# 183 SNES Function norm 2.451828784785e-08
# 184 SNES Function norm 2.714130175309e-08
# 185 SNES Function norm 2.623409042704e-08
# 186 SNES Function norm 3.079235951331e-08
# 187 SNES Function norm 2.514848091081e-08
# 188 SNES Function norm 2.604798325887e-08
# 189 SNES Function norm 2.881366771674e-08
# 190 SNES Function norm 2.680526240708e-08
# 191 SNES Function norm 2.570539531276e-08
# 192 SNES Function norm 2.476984199781e-08
# 193 SNES Function norm 2.640776901613e-08
# 194 SNES Function norm 2.866871986605e-08
# 195 SNES Function norm 2.694440022172e-08
# 196 SNES Function norm 2.503356829462e-08
# 197 SNES Function norm 2.840043435340e-08
# 198 SNES Function norm 2.501907341559e-08
# 199 SNES Function norm 2.341153651870e-08
# 200 SNES Function norm 5.022538033374e-08
# 201 SNES Function norm 2.822498426347e-08
# 202 SNES Function norm 2.539928794356e-08
# 203 SNES Function norm 2.662413987219e-08
# 204 SNES Function norm 2.508412295933e-08
# 205 SNES Function norm 2.655058052272e-08
# 206 SNES Function norm 2.791496577049e-08
# 207 SNES Function norm 2.809111329689e-08
# 208 SNES Function norm 2.428597630042e-08
# 209 SNES Function norm 2.580684190427e-08
# 210 SNES Function norm 2.349010778643e-08
# 211 SNES Function norm 2.619906467336e-08
# 212 SNES Function norm 3.060010441259e-08
# 213 SNES Function norm 2.624250852963e-08
# 214 SNES Function norm 2.565107297680e-08
# 215 SNES Function norm 2.914862042016e-08
# 216 SNES Function norm 4.456437069780e-08
# 217 SNES Function norm 2.489819646870e-08
# 218 SNES Function norm 2.482418383174e-08
# 219 SNES Function norm 2.793849534880e-08
# 220 SNES Function norm 2.670507833434e-08
# 221 SNES Function norm 3.218475502831e-08
# 222 SNES Function norm 2.766650405552e-08
# 223 SNES Function norm 2.593963625855e-08
# 224 SNES Function norm 2.672626581481e-08
# 225 SNES Function norm 2.858115344309e-08
# 226 SNES Function norm 2.613752682902e-08
# 227 SNES Function norm 2.794594087025e-08
# 228 SNES Function norm 2.480170246836e-08
# 229 SNES Function norm 2.785475656696e-08
# 230 SNES Function norm 2.602983883143e-08
# 231 SNES Function norm 2.705431748702e-08
# 232 SNES Function norm 3.578144237652e-08
# 233 SNES Function norm 2.442260228189e-08
# 234 SNES Function norm 2.813687038819e-08
# 235 SNES Function norm 2.412395566894e-08
# 236 SNES Function norm 2.810471386517e-08
# 237 SNES Function norm 4.060521855402e-08
# 238 SNES Function norm 2.598392792141e-08
# 239 SNES Function norm 2.827624015519e-08
# 240 SNES Function norm 2.467922499129e-08
# 241 SNES Function norm 2.908337438484e-08
# 242 SNES Function norm 2.551759964697e-08
# 243 SNES Function norm 2.556279686454e-08
# 244 SNES Function norm 2.666272958964e-08
# 245 SNES Function norm 2.776991720443e-08
# 246 SNES Function norm 2.742670102135e-08
# 247 SNES Function norm 2.356847258969e-08
# 248 SNES Function norm 2.566046555235e-08
# 249 SNES Function norm 2.930486788128e-08
# 250 SNES Function norm 2.702797536653e-08
# 251 SNES Function norm 2.827375013186e-08
# 252 SNES Function norm 3.498026981472e-08
# 253 SNES Function norm 2.465723257752e-08
# 254 SNES Function norm 3.043028072182e-08
# 255 SNES Function norm 2.358069682163e-08
# 256 SNES Function norm 2.528424533574e-08
# 257 SNES Function norm 2.556864241755e-08
# 258 SNES Function norm 2.717858414618e-08
# 259 SNES Function norm 2.746571021372e-08
# 260 SNES Function norm 2.315135167575e-08
# 261 SNES Function norm 2.564090600809e-08
# 262 SNES Function norm 2.421381698872e-08
# 263 SNES Function norm 1.201766122885e-07
# 264 SNES Function norm 2.627820237479e-08
# 265 SNES Function norm 2.797905106904e-08
# 266 SNES Function norm 2.714976229067e-08
# 267 SNES Function norm 4.895695248835e-08
# 268 SNES Function norm 2.758261596083e-08
# 269 SNES Function norm 2.780962017395e-08
# 270 SNES Function norm 2.366651640046e-08
# 271 SNES Function norm 4.306699129851e-08
# 272 SNES Function norm 2.538249064724e-08
# 273 SNES Function norm 2.443128894973e-08
# 274 SNES Function norm 2.379784848487e-08
# 275 SNES Function norm 2.649460290059e-08
# 276 SNES Function norm 2.768503357155e-08
# 277 SNES Function norm 2.704050725490e-08
# 278 SNES Function norm 2.734869052668e-08
# 279 SNES Function norm 2.858402643848e-08
# 280 SNES Function norm 2.667270850190e-08
# 281 SNES Function norm 2.976922780879e-08
# 282 SNES Function norm 2.720812145550e-08
# 283 SNES Function norm 2.718034765204e-08
# 284 SNES Function norm 2.321598165182e-08
# 285 SNES Function norm 4.044779212015e-08
# 286 SNES Function norm 2.664033718418e-08
# 287 SNES Function norm 2.438927475463e-08
# 288 SNES Function norm 2.699168000803e-08
# 289 SNES Function norm 2.667443813879e-08
# 290 SNES Function norm 2.771842417468e-08
# 291 SNES Function norm 2.697948953486e-08
# 292 SNES Function norm 2.446765788603e-08
# 293 SNES Function norm 2.665593344278e-08
# 294 SNES Function norm 2.860169291133e-08
# 295 SNES Function norm 2.759170844604e-08
# 296 SNES Function norm 2.661726589491e-08
# 297 SNES Function norm 2.819479669489e-08
# 298 SNES Function norm 2.573839727620e-08
# 299 SNES Function norm 2.815478557653e-08
# 300 SNES Function norm 2.584072376187e-08
# 301 SNES Function norm 2.557119505995e-08
# 302 SNES Function norm 2.687183482556e-08
# 303 SNES Function norm 2.371220355763e-08
# 304 SNES Function norm 2.475211231074e-08
# 305 SNES Function norm 2.403633216676e-08
# 306 SNES Function norm 2.427108154010e-08
# 307 SNES Function norm 2.622583408110e-08
# 308 SNES Function norm 2.819155262476e-08
# 309 SNES Function norm 2.872400966581e-08
# 310 SNES Function norm 2.695362223853e-08
# 311 SNES Function norm 2.910251552015e-08
# 312 SNES Function norm 2.956258027446e-08
# 313 SNES Function norm 3.650766626051e-08
# 314 SNES Function norm 2.509948253152e-08
# 315 SNES Function norm 2.661024733110e-08
# 316 SNES Function norm 2.478130729634e-08
# 317 SNES Function norm 2.673045176024e-08
# 318 SNES Function norm 2.587800606359e-08
# 319 SNES Function norm 2.844461256476e-08
# 320 SNES Function norm 2.539946535608e-08
# 321 SNES Function norm 2.769721781527e-08
# 322 SNES Function norm 2.395847464177e-08
# 323 SNES Function norm 3.112054664939e-08
# 324 SNES Function norm 2.483291218927e-08
# 325 SNES Function norm 2.669080889316e-08
# 326 SNES Function norm 2.696779527596e-08
# 327 SNES Function norm 2.684087962999e-08
# 328 SNES Function norm 2.792522199061e-08
# 329 SNES Function norm 2.518009921148e-08
# 330 SNES Function norm 2.662376302105e-08
# 331 SNES Function norm 2.655860622903e-08
# 332 SNES Function norm 2.495700851197e-08
# 333 SNES Function norm 2.637606162413e-08
# 334 SNES Function norm 2.534441164509e-08
# 335 SNES Function norm 2.814486875415e-08
# 336 SNES Function norm 2.699383490364e-08
# 337 SNES Function norm 2.904197446533e-08
# 338 SNES Function norm 3.567382844160e-08
# 339 SNES Function norm 2.597568371510e-08
# 340 SNES Function norm 2.679923443362e-08
# 341 SNES Function norm 2.702729428716e-08
# 342 SNES Function norm 2.587267545482e-08
# 343 SNES Function norm 2.655426610523e-08
# 344 SNES Function norm 2.734027702667e-08
# 345 SNES Function norm 3.886211351691e-08
# 346 SNES Function norm 2.418575508894e-08
# 347 SNES Function norm 2.915194409446e-08
# 348 SNES Function norm 2.625320560123e-08
# 349 SNES Function norm 2.440064903958e-08
# 350 SNES Function norm 3.479733015171e-08
# 351 SNES Function norm 2.761532332618e-08
# 352 SNES Function norm 2.778650095876e-08
# 353 SNES Function norm 2.629149149003e-08
# 354 SNES Function norm 2.563804317329e-08
# 355 SNES Function norm 2.959752607337e-08
# 356 SNES Function norm 2.643544690958e-08
# 357 SNES Function norm 2.870603088987e-08
# 358 SNES Function norm 3.467120742068e-08
# 359 SNES Function norm 2.413741602245e-08
# 360 SNES Function norm 2.899690303433e-08
# 361 SNES Function norm 2.572970896941e-08
# 362 SNES Function norm 2.927670135753e-08
# 363 SNES Function norm 2.782615418157e-08
# 364 SNES Function norm 2.457061835099e-08
# 365 SNES Function norm 2.543601440664e-08
# 366 SNES Function norm 3.072095505179e-08
# 367 SNES Function norm 2.663493925727e-08
# 368 SNES Function norm 2.717253448155e-08
# 369 SNES Function norm 2.966868675544e-08
# 370 SNES Function norm 2.631342326880e-08
# 371 SNES Function norm 2.358238285833e-08
# 372 SNES Function norm 2.715668143794e-08
# 373 SNES Function norm 2.554052751399e-08
# 374 SNES Function norm 2.829130545170e-08
# 375 SNES Function norm 2.371630138327e-08
# 376 SNES Function norm 2.559692492939e-08
# 377 SNES Function norm 2.903893696736e-08
# 378 SNES Function norm 2.641510228661e-08
# 379 SNES Function norm 2.725327415784e-08
# 380 SNES Function norm 2.497330139796e-08
# 381 SNES Function norm 2.946469991105e-08
# 382 SNES Function norm 2.460564613349e-08
# 383 SNES Function norm 2.388777782030e-08
# 384 SNES Function norm 2.618938823561e-08
# 385 SNES Function norm 2.665332556049e-08
# 386 SNES Function norm 2.931502987663e-08
# 387 SNES Function norm 3.361530626600e-08
# 388 SNES Function norm 2.480897733270e-08
# 389 SNES Function norm 2.810351828333e-08
# 390 SNES Function norm 2.560145594653e-08
# 391 SNES Function norm 2.977404900318e-08
# 392 SNES Function norm 2.492397962193e-08
# 393 SNES Function norm 2.881603840585e-08
# 394 SNES Function norm 2.351260205781e-08
# 395 SNES Function norm 2.715851594168e-08
# 396 SNES Function norm 2.879300744981e-08
# 397 SNES Function norm 2.644810118038e-08
# 398 SNES Function norm 2.787624968123e-08
# 399 SNES Function norm 2.460689198928e-08
# 400 SNES Function norm 2.694468690596e-08
# 401 SNES Function norm 2.576195473735e-08
# 402 SNES Function norm 2.706127427766e-08
# 403 SNES Function norm 2.574655420987e-08
# 404 SNES Function norm 2.377399234425e-08
# 405 SNES Function norm 2.599769158299e-08
# 406 SNES Function norm 3.272867582413e-08
# 407 SNES Function norm 2.828196748036e-08
# 408 SNES Function norm 6.115693691876e-08
# 409 SNES Function norm 2.554210466555e-08
# 410 SNES Function norm 7.623284953345e-08
# 411 SNES Function norm 2.284657194286e-08
# 412 SNES Function norm 2.625393905870e-08
# 413 SNES Function norm 2.469200719455e-08
# 414 SNES Function norm 2.685462944165e-08
# 415 SNES Function norm 2.743778786674e-08
# 416 SNES Function norm 2.509202493942e-08
# 417 SNES Function norm 2.855674418060e-08
# 418 SNES Function norm 2.800189170676e-08
# 419 SNES Function norm 3.253721272910e-08
# 420 SNES Function norm 2.895289878213e-08
# 421 SNES Function norm 5.773300819774e-08
# 422 SNES Function norm 2.680246495165e-08
# 423 SNES Function norm 2.531809949939e-08
# 424 SNES Function norm 3.402542075445e-08
# 425 SNES Function norm 2.589875919922e-08
# 426 SNES Function norm 2.559872417851e-08
# 427 SNES Function norm 2.543384366573e-08
# 428 SNES Function norm 2.715418355073e-08
# 429 SNES Function norm 2.530114747770e-08
# 430 SNES Function norm 2.625177911674e-08
# 431 SNES Function norm 2.496417223145e-08
# 432 SNES Function norm 2.768617790014e-08
# 433 SNES Function norm 2.830087132263e-08
# 434 SNES Function norm 2.546569850532e-08
# 435 SNES Function norm 4.380394584711e-08
# 436 SNES Function norm 3.095872597221e-08
# 437 SNES Function norm 4.072165951125e-08
# 438 SNES Function norm 2.430768851693e-08
# 439 SNES Function norm 2.747499510057e-08
# 440 SNES Function norm 2.816891233967e-08
# 441 SNES Function norm 2.898232148207e-08
# 442 SNES Function norm 3.269186134411e-08
# 443 SNES Function norm 2.744534635358e-08
# 444 SNES Function norm 2.499609706779e-08
# 445 SNES Function norm 2.582766292156e-08
# 446 SNES Function norm 2.869472433598e-08
# 447 SNES Function norm 2.655134590129e-08
# 448 SNES Function norm 3.018259878160e-08
# 449 SNES Function norm 2.571107819210e-08
# 450 SNES Function norm 2.515564858359e-08
# 451 SNES Function norm 2.778173274734e-08
# 452 SNES Function norm 2.651712902034e-08
# 453 SNES Function norm 2.928501134357e-08
# 454 SNES Function norm 2.525964950824e-08
# 455 SNES Function norm 2.412888466662e-08
# 456 SNES Function norm 2.666246311957e-08
# 457 SNES Function norm 2.692985407020e-08
# 458 SNES Function norm 2.335417861312e-08
# 459 SNES Function norm 2.676533888956e-08
# 460 SNES Function norm 2.405223678272e-08
# 461 SNES Function norm 2.648926055494e-08
# 462 SNES Function norm 2.453109538415e-08
# 463 SNES Function norm 2.848354212504e-08
# 464 SNES Function norm 2.566395838226e-08
# 465 SNES Function norm 2.442237377585e-08
# 466 SNES Function norm 2.314439948520e-08
# 467 SNES Function norm 2.656679774876e-08

# %%
if len(points_on_proc) > 0:
    import matplotlib.pyplot as plt
    plt.plot(results[:, 0], results[:, 1], "-o")
    plt.xlabel("Displacement of inner boundary")
    plt.ylabel(r"Applied pressure $q/q_{lim}$")
    plt.savefig(f"displacement_rank{MPI.COMM_WORLD.rank:d}.png")
    plt.show()
