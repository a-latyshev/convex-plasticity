# %% [markdown]
# Implementation of 2D elasto-plastic problem using FEniCS-X. The code is based on a [legacy solution](https://comet-fenics.readthedocs.io/en/latest/demo/2D_plasticity/vonMises_plasticity.py.html) for FEniCS 2019.
#
# The program was tested for 0.3.1.0 version of Dolfinx.

# %%
import convex_return_mapping as crm # there is a conflict in the oder of imported modules
import meshio
import numpy as np

import ufl
from dolfinx import fem, io, common
from mpi4py import MPI
from petsc4py import PETSc

import sys
sys.path.append("../")
import fenicsx_support as fs
sys.path.append("../../optimisation")
import plasticity_framework as pf

# %%
if MPI.COMM_WORLD.rank == 0:

    #It works with the msh4 only!!
    msh = meshio.read("thick_cylinder_coarse.msh")

    # Create and save one file for the mesh, and one file for the facets 
    triangle_mesh = fs.create_mesh(msh, "triangle", prune_z=True)
    line_mesh = fs.create_mesh(msh, "line", prune_z=True)
    meshio.write("thick_cylinder.xdmf", triangle_mesh)
    meshio.write("mt.xdmf", line_mesh)
    print(msh)
# Out:
# <meshio mesh object>
#   Number of points: 50
#   Number of cells:
#     line: 2
#     line: 14
#     line: 2
#     line: 11
#     triangle: 69
#   Cell sets: gmsh:bounding_entities
#   Point data: gmsh:dim_tags
#   Cell data: gmsh:physical, gmsh:geometrical

# %%
with io.XDMFFile(MPI.COMM_WORLD, "thick_cylinder.xdmf", "r") as xdmf:
    mesh = xdmf.read_mesh(name="Grid")
    ct = xdmf.read_meshtags(mesh, name="Grid")

mesh.topology.create_connectivity(mesh.topology.dim, mesh.topology.dim - 1)

with io.XDMFFile(MPI.COMM_WORLD, "mt.xdmf", "r") as xdmf:
    ft = xdmf.read_meshtags(mesh, name="Grid")

# %%
# elastic parameters
sig0_dim = 70e3 #[Pa]
Ri_dim = 1.0 #[m]

E = 70e3 / sig0_dim #[-]
nu = 0.3 #[-]
lmbda = E*nu/(1+nu)/(1-2*nu)
mu = fem.Constant(mesh, PETSc.ScalarType(E/2./(1+nu)))

sig0 = 250 / sig0_dim #[-]
Et = E/100.  # tangent modulus
H = E*Et/(E-Et)  # hardening modulus

Re, Ri = 1.3, 1.   # external/internal radius

# %%
deg_u = 2
deg_stress = 2
V = fem.VectorFunctionSpace(mesh, ("CG", deg_u))
We = ufl.VectorElement("Quadrature", mesh.ufl_cell(), degree=deg_stress, dim=4, quad_scheme='default')
W0e = ufl.FiniteElement("Quadrature", mesh.ufl_cell(), degree=deg_stress, quad_scheme='default')

W = fem.FunctionSpace(mesh, We)
W0 = fem.FunctionSpace(mesh, W0e)

# %%
sig = fem.Function(W)
sig_old = fem.Function(W)
p = fem.Function(W0, name="Cumulative_plastic_strain")
p_old = fem.Function(W0)
u = fem.Function(V, name="Total_displacement")
Du = fem.Function(V, name="Current_increment")
v_ = ufl.TrialFunction(V)
u_ = ufl.TestFunction(V)

deps = fem.Function(W, name="deps")

# %%
left_marker = 3
down_marker = 1
left_facets = ft.indices[ft.values == left_marker]
down_facets = ft.indices[ft.values == down_marker]
left_dofs = fem.locate_dofs_topological(V.sub(0), mesh.topology.dim-1, left_facets)
down_dofs = fem.locate_dofs_topological(V.sub(1), mesh.topology.dim-1, down_facets)

bcs = [fem.dirichletbc(PETSc.ScalarType(0), left_dofs, V.sub(0)), fem.dirichletbc(PETSc.ScalarType(0), down_dofs, V.sub(1))]

# %%
ds = ufl.Measure("ds", domain=mesh, subdomain_data=ft)
dx = ufl.Measure(
    "dx",
    domain=mesh,
    metadata={"quadrature_degree": deg_stress, "quadrature_scheme": "default"},
)

# %%
n = ufl.FacetNormal(mesh)
q_lim = float(2/np.sqrt(3)*np.log(Re/Ri)*sig0)
loading = fem.Constant(mesh, PETSc.ScalarType(0.0 * q_lim))

SQRT2 = np.sqrt(2.)

def F_ext(v):
    return -loading * ufl.inner(n, v)*ds(4)

def eps(v):
    e = ufl.sym(ufl.grad(v))
    return ufl.as_tensor([[e[0, 0], e[0, 1], 0],
                          [e[0, 1], e[1, 1], 0],
                          [0, 0, 0]])

def eps_vec(v):
    e = ufl.sym(ufl.grad(v))
    return ufl.as_vector([e[0, 0], e[1, 1], 0, SQRT2 * e[0, 1]])

def as_3D_tensor(X):
    return ufl.as_tensor([[X[0], X[3] / SQRT2, 0],
                          [X[3] / SQRT2, X[1], 0],
                          [0, 0, X[2]]])       
                          
def sigma(eps_el):
    return lmbda*ufl.tr(eps_el)*ufl.Identity(3) + 2*mu*eps_el

def deps_p(deps, old_sig, p, old_p):
    sig_n = as_3D_tensor(old_sig)
    sig_elas = sig_n + sigma(deps)
    s = ufl.dev(sig_elas)
    sig_eq = ufl.sqrt(3/2.*ufl.inner(s, s))
    f_elas = sig_eq - sig0 - H*old_p
    deps_p = ufl.conditional(f_elas > 0, (p - p_old) * (3./2. * s / sig_eq), 0*ufl.Identity(3)) # sig_eq is equal to 0 on the first iteration
    return deps_p

# %%
vonMises = crm.vonMises(sig0, H)
alpha = 0
DruckerPrager = crm.DruckerPrager(sig0, alpha, H)
material = crm.Material(crm.IsotropicElasticity(E, nu), DruckerPrager)
material = crm.Material(crm.IsotropicElasticity(E, nu), vonMises)

n_quadrature_points = len(p.x.array)

N = patch_size = 3 # or batch, or group ?
N_patches = int(n_quadrature_points / patch_size)
residue_size = n_quadrature_points % patch_size

return_mapping = crm.ReturnMapping(material, patch_size)

p_values = p.x.array[:n_quadrature_points - residue_size].reshape((-1, patch_size))
p_old_values = p_old.x.array[:n_quadrature_points - residue_size].reshape((-1, patch_size))
deps_values = deps.x.array[:4*(n_quadrature_points - residue_size)].reshape((-1, patch_size, 4))
sig_values = sig.x.array[:4*(n_quadrature_points - residue_size)].reshape((-1, patch_size, 4))
sig_old_values = sig_old.x.array[:4*(n_quadrature_points - residue_size)].reshape((-1, patch_size, 4))

if residue_size != 0:
    return_mapping_residue = crm.ReturnMapping(material, residue_size)
    
    p_values_residue = p.x.array[n_quadrature_points - residue_size:].reshape((1, residue_size))
    p_old_values_residue = p_old.x.array[n_quadrature_points - residue_size:].reshape((1, residue_size))
    deps_values_residue = deps.x.array[4*(n_quadrature_points - residue_size):].reshape((1, residue_size, 4))
    sig_values_residue = sig.x.array[4*(n_quadrature_points - residue_size):].reshape((1, residue_size, 4))
    sig_old_values_residue = sig_old.x.array[4*(n_quadrature_points - residue_size):].reshape((1, residue_size, 4))

# %%
petsc_options_SNES = {
    "snes_type": "vinewtonrsls",
    "snes_linesearch_type": "basic",
    "ksp_type": "preonly",
    "pc_type": "lu",
    "pc_factor_mat_solver_type": "mumps",
    "snes_atol": 1.0e-08,
    "snes_rtol": 1.0e-08,
    "snes_stol": 0.0,
    "snes_max_it": 500,
    "snes_monitor": "",
}

petsc_options_SNESQN = {
    "snes_type": "qn",
    "snes_qn_type": "lbfgs", #lbfgs broyden, badbroyden
    "snes_qn_m": 100,
    "snes_qn_scale_type": "jacobian", #<diagonal,none,scalar,jacobian> 	
    "snes_qn_restart_type": "none", #<powell,periodic,none> 
    "pc_type": "cholesky", # cholesky >> hypre > gamg,sor ; asm, lu, gas - don't work
    "snes_linesearch_type": "basic",
    "ksp_type": "preonly",
    "pc_factor_mat_solver_type": "mumps",
    "snes_atol": 1.0e-08,
    "snes_rtol": 1.0e-08,
    "snes_stol": 0.0,
    "snes_max_it": 500,
    "snes_monitor": "",
    # "snes_monitor_cancel": "",
}

def inside_Newton():
    tol = 1e-13
    fs.interpolate_quadrature(eps_vec(Du), deps) # eps_xy * sqrt(2.)!

    for q in range(N_patches):
        return_mapping.deps.value[:] = deps_values[q,:].T
        return_mapping.sig_old.value[:] = sig_old_values[q,:].T
        return_mapping.p_old.value = p_old_values[q,:]
        
        return_mapping.solve(derivation=False, verbose=False, eps=tol, eps_abs=tol, eps_rel=tol)
        sig_values[q,:] = return_mapping.sig.value[:].T
        p_values[q,:] = return_mapping.p.value

    if residue_size != 0: #how to improve ?
        return_mapping_residue.deps.value[:] = deps_values_residue[0,:].T
        return_mapping_residue.sig_old.value[:] = sig_old_values_residue[0,:].T
        return_mapping_residue.p_old.value = p_old_values_residue[0,:]
        
        return_mapping_residue.solve(derivation=False, verbose=False, eps=tol, eps_abs=tol, eps_rel=tol)

        sig_values_residue[0,:] = return_mapping_residue.sig.value[:].T
        p_values_residue[0,:] = return_mapping_residue.p.value

residual = ufl.inner(as_3D_tensor(sig_old) + sigma(eps(Du) - deps_p(eps(Du), sig_old, p, p_old)), eps(u_))*dx - F_ext(u_)
J = ufl.derivative(ufl.inner(sigma(eps(Du)), eps(u_))*dx, Du, v_) #TODO: check J-formula!
# J = ufl.derivative(ufl.inner(sigma(eps(Du) - deps_p(eps(Du), sig_old, p, p_old)), eps(u_))*dx, Du, v_)
snes_problem = pf.SNESProblem(residual, Du, J, bcs, petsc_options=petsc_options_SNES, inside_Newton=inside_Newton)

# %%
# Defining a cell containing (Ri, 0) point, where we calculate a value of u
x_point = np.array([[Ri, 0, 0]])
cells, points_on_proc = fs.find_cell_by_point(mesh, x_point)

# %%
Nincr = 20
load_steps = np.linspace(0, 1.1, Nincr+1)[1:]**0.5
results = np.zeros((Nincr+1, 2))

sig.vector.set(0.0)
sig_old.vector.set(0.0)
p.vector.set(0.0)
p_old.vector.set(0.0)
u.vector.set(0.0)

with common.Timer() as timer: 
    for (i, t) in enumerate(load_steps):
        loading.value = t * q_lim

        Du.x.array[:] = 0
        
        if MPI.COMM_WORLD.rank == 0:
            print(f"\n Increment: {str(i+1)}, load = {t * q_lim}")

        snes_problem.solve()

        u.vector.axpy(1, Du.vector) # u = u + 1*Du
        u.x.scatter_forward()

        p_old.x.array[:] = p.x.array        
        sig_old.x.array[:] = sig.x.array

        if len(points_on_proc) > 0:
            results[i+1, :] = (u.eval(points_on_proc, cells)[0], t)
    
    print(f'\nrank#{MPI.COMM_WORLD.rank}: Time = {timer.elapsed()[0]:.3f} (s)')
# Out:
#  Increment: 1, load = 0.0002537449238735671
#   0 SNES Function norm 8.904703628988e-05
#   1 SNES Function norm 9.352557389794e-18
#
#  Increment: 2, load = 0.00035884951272532715
#   0 SNES Function norm 3.688449012012e-05
#   1 SNES Function norm 4.187636163250e-18
#
#  Increment: 3, load = 0.0004394991003117152
#   0 SNES Function norm 2.830246470683e-05
#   1 SNES Function norm 3.037567060989e-18
#
#  Increment: 4, load = 0.0005074898477471342
#   0 SNES Function norm 2.386008146178e-05
#   1 SNES Function norm 2.216605725120e-18
#
#  Increment: 5, load = 0.0005673908987268053
#   0 SNES Function norm 2.102115375875e-05
#   1 SNES Function norm 2.307740496817e-18
#
#  Increment: 6, load = 0.000621545588311601
#   0 SNES Function norm 1.900457567762e-05
#   1 SNES Function norm 2.044193620888e-18
#
#  Increment: 7, load = 0.0006713459650144749
#   0 SNES Function norm 1.747651099238e-05
#   1 SNES Function norm 1.786084853981e-18
#
#  Increment: 8, load = 0.0007176990254506543
#   0 SNES Function norm 1.626673980976e-05
#   1 SNES Function norm 1.740949313537e-18
#
#  Increment: 9, load = 0.0007612347716207013
#   0 SNES Function norm 1.527805604887e-05
#   1 SNES Function norm 1.600988188877e-18
#
#  Increment: 10, load = 0.0008024119041465073
#   0 SNES Function norm 1.445034469374e-05
#   1 SNES Function norm 1.712400036773e-18
#
#  Increment: 11, load = 0.0008415767049459163
#   0 SNES Function norm 1.374415449426e-05
#   1 SNES Function norm 1.457622188606e-18
#
#  Increment: 12, load = 0.0008789982006234304
#   0 SNES Function norm 1.313237416911e-05
#   1 SNES Function norm 1.554253775428e-05
#   2 SNES Function norm 5.883553432822e-06
#   3 SNES Function norm 2.355123295586e-06
#   4 SNES Function norm 1.072232030128e-06
#   5 SNES Function norm 5.925224467007e-07
#   6 SNES Function norm 3.829420464656e-07
#   7 SNES Function norm 2.665998717807e-07
#   8 SNES Function norm 1.907225370310e-07
#   9 SNES Function norm 1.377829262307e-07
#  10 SNES Function norm 9.993966189796e-08
#  11 SNES Function norm 7.263791489956e-08
#  12 SNES Function norm 5.286078661717e-08
#  13 SNES Function norm 3.850308316643e-08
#  14 SNES Function norm 2.806528395885e-08
#  15 SNES Function norm 2.046960498019e-08
#  16 SNES Function norm 1.493781016405e-08
#  17 SNES Function norm 1.090642996149e-08
#  18 SNES Function norm 7.966798773693e-09
#
#  Increment: 13, load = 0.0009148903339148527
#   0 SNES Function norm 1.259575584634e-05
#   1 SNES Function norm 3.616891987246e-05
#   2 SNES Function norm 1.457053806346e-05
#   3 SNES Function norm 6.210782710379e-06
#   4 SNES Function norm 2.847649506435e-06
#   5 SNES Function norm 1.461707951023e-06
#   6 SNES Function norm 8.705971112220e-07
#   7 SNES Function norm 5.946646083426e-07
#   8 SNES Function norm 4.432525074934e-07
#   9 SNES Function norm 3.452510116562e-07
#  10 SNES Function norm 2.744780009279e-07
#  11 SNES Function norm 2.203564967522e-07
#  12 SNES Function norm 1.778066202102e-07
#  13 SNES Function norm 1.438943375692e-07
#  14 SNES Function norm 1.166698496308e-07
#  15 SNES Function norm 9.472186978780e-08
#  16 SNES Function norm 7.697973956860e-08
#  17 SNES Function norm 6.261029109178e-08
#  18 SNES Function norm 5.095597039704e-08
#  19 SNES Function norm 4.149333627559e-08
#  20 SNES Function norm 3.380340189517e-08
#  21 SNES Function norm 2.754950214376e-08
#  22 SNES Function norm 2.246034544277e-08
#  23 SNES Function norm 1.831684278425e-08
#  24 SNES Function norm 1.494175951097e-08
#  25 SNES Function norm 1.219152013026e-08
#  26 SNES Function norm 9.949677510783e-09
#
#  Increment: 14, load = 0.0009494265687679238
#   0 SNES Function norm 1.211953166193e-05
#   1 SNES Function norm 3.767025662599e-05
#   2 SNES Function norm 1.641176426594e-05
#   3 SNES Function norm 7.413747641370e-06
#   4 SNES Function norm 3.518939722456e-06
#   5 SNES Function norm 1.809167402695e-06
#   6 SNES Function norm 1.065199408814e-06
#   7 SNES Function norm 7.262692453547e-07
#   8 SNES Function norm 5.444960958464e-07
#   9 SNES Function norm 4.263304375455e-07
#  10 SNES Function norm 3.400665633444e-07
#  11 SNES Function norm 2.739779825636e-07
#  12 SNES Function norm 2.223904885412e-07
#  13 SNES Function norm 1.817334349465e-07
#  14 SNES Function norm 1.494407340333e-07
#  15 SNES Function norm 1.235899162941e-07
#  16 SNES Function norm 1.027295563158e-07
#  17 SNES Function norm 8.576364077922e-08
#  18 SNES Function norm 7.186347799259e-08
#  19 SNES Function norm 6.039973098197e-08
#  20 SNES Function norm 5.089092711631e-08
#  21 SNES Function norm 4.296517107097e-08
#  22 SNES Function norm 3.633208955779e-08
#  23 SNES Function norm 3.076237976535e-08
#  24 SNES Function norm 2.607297387871e-08
#  25 SNES Function norm 2.211620027513e-08
#  26 SNES Function norm 1.877184357553e-08
#  27 SNES Function norm 1.594124484155e-08
#  28 SNES Function norm 1.354288385142e-08
#  29 SNES Function norm 1.150901730669e-08
#  30 SNES Function norm 9.783083851621e-09
#
#  Increment: 15, load = 0.0009827498643469941
#   0 SNES Function norm 1.169410033307e-05
#   1 SNES Function norm 3.334703052421e-05
#   2 SNES Function norm 1.815234111887e-05
#   3 SNES Function norm 1.029520152643e-05
#   4 SNES Function norm 5.941167447163e-06
#   5 SNES Function norm 3.466867459917e-06
#   6 SNES Function norm 2.052739884330e-06
#   7 SNES Function norm 1.245296395526e-06
#   8 SNES Function norm 7.859980568784e-07
#   9 SNES Function norm 5.252809667506e-07
#  10 SNES Function norm 3.757909168018e-07
#  11 SNES Function norm 2.868869931681e-07
#  12 SNES Function norm 2.303549736881e-07
#  13 SNES Function norm 1.913658334673e-07
#  14 SNES Function norm 1.624362213980e-07
#  15 SNES Function norm 1.397786044102e-07
#  16 SNES Function norm 1.213791330503e-07
#  17 SNES Function norm 1.060777651852e-07
#  18 SNES Function norm 9.314536280781e-08
#  19 SNES Function norm 8.208760876603e-08
#  20 SNES Function norm 7.254966522172e-08
#  21 SNES Function norm 6.426621377972e-08
#  22 SNES Function norm 5.703291271764e-08
#  23 SNES Function norm 5.068879821098e-08
#  24 SNES Function norm 4.510470081503e-08
#  25 SNES Function norm 4.017533771672e-08
#  26 SNES Function norm 3.581368897016e-08
#  27 SNES Function norm 3.194695693809e-08
#  28 SNES Function norm 2.851361639865e-08
#  29 SNES Function norm 2.546116808771e-08
#  30 SNES Function norm 2.274448555172e-08
#  31 SNES Function norm 2.032451361690e-08
#  32 SNES Function norm 1.816727265157e-08
#  33 SNES Function norm 1.624306313883e-08
#  34 SNES Function norm 1.452582187476e-08
#  35 SNES Function norm 1.299261357451e-08
#  36 SNES Function norm 1.162319975793e-08
#  37 SNES Function norm 1.039968653671e-08
#  38 SNES Function norm 9.306210622872e-09
#
#  Increment: 16, load = 0.0010149796954942684
#   0 SNES Function norm 1.131022596888e-05
#   1 SNES Function norm 3.162140265908e-05
#   2 SNES Function norm 1.988845285172e-05
#   3 SNES Function norm 1.312772275479e-05
#   4 SNES Function norm 8.796558957934e-06
#   5 SNES Function norm 5.941368495688e-06
#   6 SNES Function norm 4.038097544968e-06
#   7 SNES Function norm 2.774474663901e-06
#   8 SNES Function norm 1.927564714994e-06
#   9 SNES Function norm 1.361942473349e-06
#  10 SNES Function norm 9.867939161293e-07
#  11 SNES Function norm 7.399551016121e-07
#  12 SNES Function norm 5.783231162278e-07
#  13 SNES Function norm 4.718885110670e-07
#  14 SNES Function norm 4.001342055561e-07
#  15 SNES Function norm 3.496286910594e-07
#  16 SNES Function norm 3.120430358974e-07
#  17 SNES Function norm 2.824451858820e-07
#  18 SNES Function norm 2.579905722041e-07
#  19 SNES Function norm 2.370438021856e-07
#  20 SNES Function norm 2.186466444357e-07
#  21 SNES Function norm 2.022158175951e-07
#  22 SNES Function norm 1.873771702004e-07
#  23 SNES Function norm 1.738759298305e-07
#  24 SNES Function norm 1.615279566736e-07
#  25 SNES Function norm 1.501929064630e-07
#  26 SNES Function norm 1.397590250442e-07
#  27 SNES Function norm 1.301342700460e-07
#  28 SNES Function norm 1.212408661628e-07
#  29 SNES Function norm 1.130118429594e-07
#  30 SNES Function norm 1.053886983067e-07
#  31 SNES Function norm 9.831977927227e-08
#  32 SNES Function norm 9.175910910503e-08
#  33 SNES Function norm 8.566547450092e-08
#  34 SNES Function norm 8.000175561978e-08
#  35 SNES Function norm 7.473437355424e-08
#  36 SNES Function norm 6.983284084554e-08
#  37 SNES Function norm 6.526940283366e-08
#  38 SNES Function norm 6.101872492281e-08
#  39 SNES Function norm 5.705763322754e-08
#  40 SNES Function norm 5.336489319301e-08
#  41 SNES Function norm 4.992101458523e-08
#  42 SNES Function norm 4.670808091350e-08
#  43 SNES Function norm 4.370960681035e-08
#  44 SNES Function norm 4.091039700327e-08
#  45 SNES Function norm 3.829643852474e-08
#  46 SNES Function norm 3.585479229734e-08
#  47 SNES Function norm 3.357350265268e-08
#  48 SNES Function norm 3.144150811262e-08
#  49 SNES Function norm 2.944857501707e-08
#  50 SNES Function norm 2.758521867667e-08
#  51 SNES Function norm 2.584265249638e-08
#  52 SNES Function norm 2.421272360100e-08
#  53 SNES Function norm 2.268786540142e-08
#  54 SNES Function norm 2.126105400703e-08
#  55 SNES Function norm 1.992576076794e-08
#  56 SNES Function norm 1.867591746869e-08
#  57 SNES Function norm 1.750588127406e-08
#  58 SNES Function norm 1.641039842255e-08
#  59 SNES Function norm 1.538458144954e-08
#  60 SNES Function norm 1.442387971592e-08
#  61 SNES Function norm 1.352404863254e-08
#  62 SNES Function norm 1.268113546285e-08
#  63 SNES Function norm 1.189145446899e-08
#  64 SNES Function norm 1.115156846460e-08
#  65 SNES Function norm 1.045826979973e-08
#  66 SNES Function norm 9.808564868392e-09
#
#  Increment: 17, load = 0.0010462171230950295
#   0 SNES Function norm 1.096226903639e-05
#   1 SNES Function norm 3.244113230271e-05
#   2 SNES Function norm 2.176767988318e-05
#   3 SNES Function norm 1.516072782016e-05
#   4 SNES Function norm 1.089867740364e-05
#   5 SNES Function norm 8.319912691224e-06
#   6 SNES Function norm 6.493045005683e-06
#   7 SNES Function norm 5.115177850333e-06
#   8 SNES Function norm 4.043218946554e-06
#   9 SNES Function norm 3.191482270530e-06
#  10 SNES Function norm 2.517563773203e-06
#  11 SNES Function norm 1.998141442125e-06
#  12 SNES Function norm 1.595215719232e-06
#  13 SNES Function norm 1.281844447810e-06
#  14 SNES Function norm 1.037796986858e-06
#  15 SNES Function norm 8.475860042494e-07
#  16 SNES Function norm 6.992243397188e-07
#  17 SNES Function norm 5.833642640357e-07
#  18 SNES Function norm 4.926813927520e-07
#  19 SNES Function norm 4.214263487955e-07
#  20 SNES Function norm 3.650937526755e-07
#  21 SNES Function norm 3.201722291919e-07
#  22 SNES Function norm 2.839487969743e-07
#  23 SNES Function norm 2.543496659210e-07
#  24 SNES Function norm 2.298070731169e-07
#  25 SNES Function norm 2.091472902744e-07
#  26 SNES Function norm 1.914977182293e-07
#  27 SNES Function norm 1.762118460050e-07
#  28 SNES Function norm 1.628103339820e-07
#  29 SNES Function norm 1.509360783786e-07
#  30 SNES Function norm 1.403206860967e-07
#  31 SNES Function norm 1.307599874831e-07
#  32 SNES Function norm 1.220963469162e-07
#  33 SNES Function norm 1.142060160012e-07
#  34 SNES Function norm 1.069901468215e-07
#  35 SNES Function norm 1.003683864780e-07
#  36 SNES Function norm 9.427432709510e-08
#  37 SNES Function norm 8.865223867144e-08
#  38 SNES Function norm 8.345470191128e-08
#  39 SNES Function norm 7.864089112560e-08
#  40 SNES Function norm 7.417529131377e-08
#  41 SNES Function norm 7.002673653951e-08
#  42 SNES Function norm 6.616767817182e-08
#  43 SNES Function norm 6.257361211607e-08
#  44 SNES Function norm 5.922262872546e-08
#  45 SNES Function norm 5.609504936382e-08
#  46 SNES Function norm 5.317313321667e-08
#  47 SNES Function norm 5.044083288974e-08
#  48 SNES Function norm 4.788358759020e-08
#  49 SNES Function norm 4.548815650818e-08
#  50 SNES Function norm 4.324246779512e-08
#  51 SNES Function norm 4.113549927196e-08
#  52 SNES Function norm 3.915715932900e-08
#  53 SNES Function norm 3.729820217761e-08
#  54 SNES Function norm 3.555013642578e-08
#  55 SNES Function norm 3.390516212062e-08
#  56 SNES Function norm 3.235609564080e-08
#  57 SNES Function norm 3.089631998990e-08
#  58 SNES Function norm 2.951973176052e-08
#  59 SNES Function norm 2.822069849076e-08
#  60 SNES Function norm 2.699401052890e-08
#  61 SNES Function norm 2.583485659469e-08
#  62 SNES Function norm 2.473877860654e-08
#  63 SNES Function norm 2.370165192204e-08
#  64 SNES Function norm 2.271965239441e-08
#  65 SNES Function norm 2.178923471473e-08
#  66 SNES Function norm 2.090711136285e-08
#  67 SNES Function norm 2.007022995596e-08
#  68 SNES Function norm 1.927575444682e-08
#  69 SNES Function norm 1.852105420336e-08
#  70 SNES Function norm 1.780367845466e-08
#  71 SNES Function norm 1.712135272994e-08
#  72 SNES Function norm 1.647195956933e-08
#  73 SNES Function norm 1.585352834002e-08
#  74 SNES Function norm 1.526422265269e-08
#  75 SNES Function norm 1.470233416869e-08
#  76 SNES Function norm 1.416627146102e-08
#  77 SNES Function norm 1.365454747375e-08
#  78 SNES Function norm 1.316577844708e-08
#  79 SNES Function norm 1.269867037068e-08
#  80 SNES Function norm 1.225202017499e-08
#  81 SNES Function norm 1.182469753287e-08
#  82 SNES Function norm 1.141564983034e-08
#  83 SNES Function norm 1.102389377512e-08
#  84 SNES Function norm 1.064850737533e-08
#  85 SNES Function norm 1.028862908635e-08
#  86 SNES Function norm 9.943452750491e-09
#
#  Increment: 18, load = 0.0010765485381759813
#   0 SNES Function norm 1.064440040785e-05
#   1 SNES Function norm 3.029616177349e-05
#   2 SNES Function norm 2.335047465785e-05
#   3 SNES Function norm 1.967162953129e-05
#   4 SNES Function norm 1.685488473342e-05
#   5 SNES Function norm 1.488374323161e-05
#   6 SNES Function norm 1.337560487436e-05
#   7 SNES Function norm 1.197973508137e-05
#   8 SNES Function norm 1.069749750333e-05
#   9 SNES Function norm 9.536835032288e-06
#  10 SNES Function norm 8.495243372817e-06
#  11 SNES Function norm 7.564985399969e-06
#  12 SNES Function norm 6.730123280744e-06
#  13 SNES Function norm 5.954096351297e-06
#  14 SNES Function norm 5.281884948854e-06
#  15 SNES Function norm 4.695185813376e-06
#  16 SNES Function norm 4.180447957042e-06
#  17 SNES Function norm 3.727064381812e-06
#  18 SNES Function norm 3.272770189000e-06
#  19 SNES Function norm 2.853384078310e-06
#  20 SNES Function norm 2.519816998433e-06
#  21 SNES Function norm 2.234000488853e-06
#  22 SNES Function norm 2.016411149644e-06
#  23 SNES Function norm 1.843493895248e-06
#  24 SNES Function norm 1.695068219156e-06
#  25 SNES Function norm 1.572452405297e-06
#  26 SNES Function norm 1.467191411824e-06
#  27 SNES Function norm 1.374547008120e-06
#  28 SNES Function norm 1.291570944489e-06
#  29 SNES Function norm 1.216322279356e-06
#  30 SNES Function norm 1.147470328834e-06
#  31 SNES Function norm 1.084064550113e-06
#  32 SNES Function norm 1.025396318661e-06
#  33 SNES Function norm 9.709148466365e-07
#  34 SNES Function norm 9.201755638615e-07
#  35 SNES Function norm 8.728082716122e-07
#  36 SNES Function norm 8.284972039658e-07
#  37 SNES Function norm 7.869683085074e-07
#  38 SNES Function norm 7.479808912820e-07
#  39 SNES Function norm 7.113218937125e-07
#  40 SNES Function norm 6.768017282076e-07
#  41 SNES Function norm 6.435324570178e-07
#  42 SNES Function norm 6.110570858662e-07
#  43 SNES Function norm 5.805680897468e-07
#  44 SNES Function norm 5.518457865947e-07
#  45 SNES Function norm 5.214206819084e-07
#  46 SNES Function norm 4.940341080129e-07
#  47 SNES Function norm 4.690541387509e-07
#  48 SNES Function norm 4.445062390951e-07
#  49 SNES Function norm 4.214114068167e-07
#  50 SNES Function norm 4.000434593094e-07
#  51 SNES Function norm 3.801189030676e-07
#  52 SNES Function norm 3.621999945113e-07
#  53 SNES Function norm 3.457062151152e-07
#  54 SNES Function norm 3.303354500771e-07
#  55 SNES Function norm 3.156801523908e-07
#  56 SNES Function norm 3.017286514338e-07
#  57 SNES Function norm 2.885034942540e-07
#  58 SNES Function norm 2.760975760629e-07
#  59 SNES Function norm 2.644035471118e-07
#  60 SNES Function norm 2.533412986853e-07
#  61 SNES Function norm 2.428496730079e-07
#  62 SNES Function norm 2.328797382517e-07
#  63 SNES Function norm 2.233910311000e-07
#  64 SNES Function norm 2.143492335932e-07
#  65 SNES Function norm 2.057246702637e-07
#  66 SNES Function norm 1.974912554767e-07
#  67 SNES Function norm 1.896257307107e-07
#  68 SNES Function norm 1.821071325391e-07
#  69 SNES Function norm 1.749163780195e-07
#  70 SNES Function norm 1.680359772310e-07
#  71 SNES Function norm 1.614498023024e-07
#  72 SNES Function norm 1.551429122370e-07
#  73 SNES Function norm 1.491014035415e-07
#  74 SNES Function norm 1.433123069340e-07
#  75 SNES Function norm 1.377634882071e-07
#  76 SNES Function norm 1.324435682192e-07
#  77 SNES Function norm 1.273418630571e-07
#  78 SNES Function norm 1.224483113143e-07
#  79 SNES Function norm 1.177534336978e-07
#  80 SNES Function norm 1.132482937419e-07
#  81 SNES Function norm 1.089244328252e-07
#  82 SNES Function norm 1.047738620452e-07
#  83 SNES Function norm 1.007890095131e-07
#  84 SNES Function norm 9.696270804012e-08
#  85 SNES Function norm 9.328814428072e-08
#  86 SNES Function norm 8.975886141756e-08
#  87 SNES Function norm 8.636871177573e-08
#  88 SNES Function norm 8.311186172064e-08
#  89 SNES Function norm 7.998274826334e-08
#  90 SNES Function norm 7.697607350244e-08
#  91 SNES Function norm 7.408679824517e-08
#  92 SNES Function norm 7.131010220955e-08
#  93 SNES Function norm 6.864140300360e-08
#  94 SNES Function norm 6.607630808600e-08
#  95 SNES Function norm 6.352858102790e-08
#  96 SNES Function norm 6.097194793000e-08
#  97 SNES Function norm 5.857189389073e-08
#  98 SNES Function norm 5.631588533300e-08
#  99 SNES Function norm 5.419003957357e-08
# 100 SNES Function norm 5.218135453655e-08
# 101 SNES Function norm 5.027831442911e-08
# 102 SNES Function norm 4.847105258147e-08
# 103 SNES Function norm 4.675116841254e-08
# 104 SNES Function norm 4.511149518802e-08
# 105 SNES Function norm 4.354587245192e-08
# 106 SNES Function norm 4.204897106094e-08
# 107 SNES Function norm 4.061611719066e-08
# 108 SNES Function norm 3.924318891261e-08
# 109 SNES Function norm 3.792651635674e-08
# 110 SNES Function norm 3.666280059291e-08
# 111 SNES Function norm 3.544906575061e-08
# 112 SNES Function norm 3.428260309140e-08
# 113 SNES Function norm 3.316093675073e-08
# 114 SNES Function norm 3.208179267762e-08
# 115 SNES Function norm 3.104307627908e-08
# 116 SNES Function norm 3.004284306200e-08
# 117 SNES Function norm 2.907928668237e-08
# 118 SNES Function norm 2.815073003939e-08
# 119 SNES Function norm 2.725560277807e-08
# 120 SNES Function norm 2.639243059760e-08
# 121 SNES Function norm 2.555983557809e-08
# 122 SNES Function norm 2.475651775892e-08
# 123 SNES Function norm 2.398125579784e-08
# 124 SNES Function norm 2.323289462004e-08
# 125 SNES Function norm 2.251034248467e-08
# 126 SNES Function norm 2.181257177004e-08
# 127 SNES Function norm 2.113859685017e-08
# 128 SNES Function norm 2.048749639812e-08
# 129 SNES Function norm 1.985838172518e-08
# 130 SNES Function norm 1.925041283852e-08
# 131 SNES Function norm 1.866280206743e-08
# 132 SNES Function norm 1.809477519089e-08
# 133 SNES Function norm 1.754561519388e-08
# 134 SNES Function norm 1.701461800715e-08
# 135 SNES Function norm 1.650113178459e-08
# 136 SNES Function norm 1.600451744345e-08
# 137 SNES Function norm 1.552417201475e-08
# 138 SNES Function norm 1.505950976956e-08
# 139 SNES Function norm 1.460997860664e-08
# 140 SNES Function norm 1.417504357052e-08
# 141 SNES Function norm 1.375419372172e-08
# 142 SNES Function norm 1.334693965858e-08
# 143 SNES Function norm 1.295280693988e-08
# 144 SNES Function norm 1.257134293341e-08
# 145 SNES Function norm 1.220211456010e-08
# 146 SNES Function norm 1.184470209748e-08
# 147 SNES Function norm 1.149870192471e-08
# 148 SNES Function norm 1.116372698214e-08
# 149 SNES Function norm 1.083940453502e-08
# 150 SNES Function norm 1.052537462009e-08
# 151 SNES Function norm 1.022129311249e-08
# 152 SNES Function norm 9.926824346481e-09
#
#  Increment: 19, load = 0.0011060484806013002
#   0 SNES Function norm 1.035603361775e-05
#   1 SNES Function norm 2.835029604713e-05
#   2 SNES Function norm 2.801107833229e-05
#   3 SNES Function norm 2.750463586299e-05
#   4 SNES Function norm 2.697406881314e-05
#   5 SNES Function norm 2.645490627210e-05
#   6 SNES Function norm 2.595494149307e-05
#   7 SNES Function norm 2.547496316912e-05
#   8 SNES Function norm 2.501406351732e-05
#   9 SNES Function norm 2.457099801657e-05
#  10 SNES Function norm 2.414452955490e-05
#  11 SNES Function norm 2.373350925419e-05
#  12 SNES Function norm 2.333688891280e-05
#  13 SNES Function norm 2.295371611120e-05
#  14 SNES Function norm 2.258312553830e-05
#  15 SNES Function norm 2.222433006401e-05
#  16 SNES Function norm 2.187661248698e-05
#  17 SNES Function norm 2.153931811234e-05
#  18 SNES Function norm 2.121184816370e-05
#  19 SNES Function norm 2.089365394781e-05
#  20 SNES Function norm 2.058423169882e-05
#  21 SNES Function norm 2.028311801444e-05
#  22 SNES Function norm 1.998988583981e-05
#  23 SNES Function norm 1.970414086424e-05
#  24 SNES Function norm 1.942551840867e-05
#  25 SNES Function norm 1.915368056680e-05
#  26 SNES Function norm 1.888831375818e-05
#  27 SNES Function norm 1.862912643246e-05
#  28 SNES Function norm 1.837584718801e-05
#  29 SNES Function norm 1.812822290469e-05
#  30 SNES Function norm 1.788601718984e-05
#  31 SNES Function norm 1.764900898002e-05
#  32 SNES Function norm 1.741699122719e-05
#  33 SNES Function norm 1.718976973555e-05
#  34 SNES Function norm 1.696716214584e-05
#  35 SNES Function norm 1.674899699763e-05
#  36 SNES Function norm 1.653511287679e-05
#  37 SNES Function norm 1.632535761670e-05
#  38 SNES Function norm 1.611958764729e-05
#  39 SNES Function norm 1.591766731203e-05
#  40 SNES Function norm 1.571946832628e-05
#  41 SNES Function norm 1.552486920859e-05
#  42 SNES Function norm 1.533375483824e-05
#  43 SNES Function norm 1.514601599630e-05
#  44 SNES Function norm 1.496154896151e-05
#  45 SNES Function norm 1.478025514140e-05
#  46 SNES Function norm 1.460204072786e-05
#  47 SNES Function norm 1.442681637908e-05
#  48 SNES Function norm 1.425449695334e-05
#  49 SNES Function norm 1.408500122345e-05
#  50 SNES Function norm 1.391825163305e-05
#  51 SNES Function norm 1.375417408784e-05
#  52 SNES Function norm 1.359269772326e-05
#  53 SNES Function norm 1.343375473093e-05
#  54 SNES Function norm 1.327728015521e-05
#  55 SNES Function norm 1.312321175545e-05
#  56 SNES Function norm 1.297148984064e-05
#  57 SNES Function norm 1.282205708592e-05
#  58 SNES Function norm 1.267485847667e-05
#  59 SNES Function norm 1.252984113260e-05
#  60 SNES Function norm 1.238695419172e-05
#  61 SNES Function norm 1.224614870852e-05
#  62 SNES Function norm 1.210737756549e-05
#  63 SNES Function norm 1.197059538706e-05
#  64 SNES Function norm 1.183575839989e-05
#  65 SNES Function norm 1.170282436614e-05
#  66 SNES Function norm 1.157175258133e-05
#  67 SNES Function norm 1.144250372094e-05
#  68 SNES Function norm 1.131503976124e-05
#  69 SNES Function norm 1.118932400492e-05
#  70 SNES Function norm 1.106532090825e-05
#  71 SNES Function norm 1.094299612401e-05
#  72 SNES Function norm 1.082231635336e-05
#  73 SNES Function norm 1.070324939920e-05
#  74 SNES Function norm 1.058576405320e-05
#  75 SNES Function norm 1.046983004457e-05
#  76 SNES Function norm 1.035541803217e-05
#  77 SNES Function norm 1.024249955336e-05
#  78 SNES Function norm 1.013104697308e-05
#  79 SNES Function norm 1.002103346656e-05
#  80 SNES Function norm 9.912432958619e-06
#  81 SNES Function norm 9.805220143344e-06
#  82 SNES Function norm 9.699370399254e-06
#  83 SNES Function norm 9.594859787496e-06
#  84 SNES Function norm 9.491665015127e-06
#  85 SNES Function norm 9.389763424693e-06
#  86 SNES Function norm 9.289132953167e-06
#  87 SNES Function norm 9.189752116427e-06
#  88 SNES Function norm 9.091599983121e-06
#  89 SNES Function norm 8.994656158966e-06
#  90 SNES Function norm 8.898900766469e-06
#  91 SNES Function norm 8.804314425247e-06
#  92 SNES Function norm 8.710878221828e-06
#  93 SNES Function norm 8.618573713097e-06
#  94 SNES Function norm 8.527382894799e-06
#  95 SNES Function norm 8.437288193058e-06
#  96 SNES Function norm 8.348272451467e-06
#  97 SNES Function norm 8.260318910927e-06
#  98 SNES Function norm 8.173411190649e-06
#  99 SNES Function norm 8.087533289362e-06
# 100 SNES Function norm 8.002669567035e-06
# 101 SNES Function norm 7.918804727756e-06
# 102 SNES Function norm 7.835923810923e-06
# 103 SNES Function norm 7.754012187194e-06
# 104 SNES Function norm 7.673055541106e-06
# 105 SNES Function norm 7.593039864007e-06
# 106 SNES Function norm 7.513951439519e-06
# 107 SNES Function norm 7.435776842720e-06
# 108 SNES Function norm 7.358502919050e-06
# 109 SNES Function norm 7.282116795082e-06
# 110 SNES Function norm 7.206605853911e-06
# 111 SNES Function norm 7.131957733115e-06
# 112 SNES Function norm 7.058160309211e-06
# 113 SNES Function norm 6.985201706878e-06
# 114 SNES Function norm 6.913070282296e-06
# 115 SNES Function norm 6.841754613412e-06
# 116 SNES Function norm 6.771243500025e-06
# 117 SNES Function norm 6.701525955350e-06
# 118 SNES Function norm 6.632591199352e-06
# 119 SNES Function norm 6.564428653145e-06
# 120 SNES Function norm 6.497027935285e-06
# 121 SNES Function norm 6.430378854624e-06
# 122 SNES Function norm 6.364471405448e-06
# 123 SNES Function norm 6.299295763908e-06
# 124 SNES Function norm 6.234842281606e-06
# 125 SNES Function norm 6.171101483243e-06
# 126 SNES Function norm 6.108064056679e-06
# 127 SNES Function norm 6.045720857019e-06
# 128 SNES Function norm 5.984062897046e-06
# 129 SNES Function norm 5.923081344044e-06
# 130 SNES Function norm 5.862767517457e-06
# 131 SNES Function norm 5.803112881227e-06
# 132 SNES Function norm 5.744109052131e-06
# 133 SNES Function norm 5.685747772409e-06
# 134 SNES Function norm 5.628020937166e-06
# 135 SNES Function norm 5.570920561509e-06
# 136 SNES Function norm 5.514438800982e-06
# 137 SNES Function norm 5.458567934216e-06
# 138 SNES Function norm 5.403300366140e-06
# 139 SNES Function norm 5.348628622269e-06
# 140 SNES Function norm 5.294545352306e-06
# 141 SNES Function norm 5.241043314945e-06
# 142 SNES Function norm 5.188115386668e-06
# 143 SNES Function norm 5.135754555369e-06
# 144 SNES Function norm 5.083953917449e-06
# 145 SNES Function norm 5.032706676062e-06
# 146 SNES Function norm 4.982006138919e-06
# 147 SNES Function norm 4.931845715222e-06
# 148 SNES Function norm 4.882218914621e-06
# 149 SNES Function norm 4.833119344493e-06
# 150 SNES Function norm 4.784540707747e-06
# 151 SNES Function norm 4.736476801439e-06
# 152 SNES Function norm 4.688921514668e-06
# 153 SNES Function norm 4.641868825912e-06
# 154 SNES Function norm 4.595312802807e-06
# 155 SNES Function norm 4.549247598955e-06
# 156 SNES Function norm 4.503667452411e-06
# 157 SNES Function norm 4.458566684682e-06
# 158 SNES Function norm 4.413939698922e-06
# 159 SNES Function norm 4.369780976467e-06
# 160 SNES Function norm 4.326085083412e-06
# 161 SNES Function norm 4.282846652762e-06
# 162 SNES Function norm 4.240060399075e-06
# 163 SNES Function norm 4.197721110398e-06
# 164 SNES Function norm 4.155823646136e-06
# 165 SNES Function norm 4.114362937802e-06
# 166 SNES Function norm 4.073333986034e-06
# 167 SNES Function norm 4.032731861165e-06
# 168 SNES Function norm 3.992551699985e-06
# 169 SNES Function norm 3.952788706156e-06
# 170 SNES Function norm 3.913438147775e-06
# 171 SNES Function norm 3.874495356540e-06
# 172 SNES Function norm 3.835955727722e-06
# 173 SNES Function norm 3.797814717832e-06
# 174 SNES Function norm 3.760067843635e-06
# 175 SNES Function norm 3.722710681098e-06
# 176 SNES Function norm 3.685738865269e-06
# 177 SNES Function norm 3.649148088471e-06
# 178 SNES Function norm 3.612934099647e-06
# 179 SNES Function norm 3.577092702146e-06
# 180 SNES Function norm 3.541619755491e-06
# 181 SNES Function norm 3.506511170659e-06
# 182 SNES Function norm 3.471762916445e-06
# 183 SNES Function norm 3.437371005847e-06
# 184 SNES Function norm 3.403331507891e-06
# 185 SNES Function norm 3.369640541146e-06
# 186 SNES Function norm 3.336294272941e-06
# 187 SNES Function norm 3.303288919998e-06
# 188 SNES Function norm 3.270620745945e-06
# 189 SNES Function norm 3.238286061664e-06
# 190 SNES Function norm 3.206281224823e-06
# 191 SNES Function norm 3.174602637829e-06
# 192 SNES Function norm 3.143246748956e-06
# 193 SNES Function norm 3.112210049487e-06
# 194 SNES Function norm 3.081489074864e-06
# 195 SNES Function norm 3.051080404399e-06
# 196 SNES Function norm 3.020980673285e-06
# 197 SNES Function norm 2.991186485063e-06
# 198 SNES Function norm 2.961694613136e-06
# 199 SNES Function norm 2.932501768494e-06
# 200 SNES Function norm 2.903604734790e-06
# 201 SNES Function norm 2.875000334922e-06
# 202 SNES Function norm 2.846685428042e-06
# 203 SNES Function norm 2.818656912183e-06
# 204 SNES Function norm 2.790911722768e-06
# 205 SNES Function norm 2.763446830686e-06
# 206 SNES Function norm 2.736259244712e-06
# 207 SNES Function norm 2.709346009012e-06
# 208 SNES Function norm 2.682704201418e-06
# 209 SNES Function norm 2.656330935990e-06
# 210 SNES Function norm 2.630223360399e-06
# 211 SNES Function norm 2.604378653258e-06
# 212 SNES Function norm 2.578794032981e-06
# 213 SNES Function norm 2.553466745964e-06
# 214 SNES Function norm 2.528394071531e-06
# 215 SNES Function norm 2.503573321295e-06
# 216 SNES Function norm 2.479001837248e-06
# 217 SNES Function norm 2.454676993467e-06
# 218 SNES Function norm 2.430596194184e-06
# 219 SNES Function norm 2.406756873942e-06
# 220 SNES Function norm 2.383156494029e-06
# 221 SNES Function norm 2.359792551162e-06
# 222 SNES Function norm 2.336662566070e-06
# 223 SNES Function norm 2.313764088986e-06
# 224 SNES Function norm 2.291094699098e-06
# 225 SNES Function norm 2.268652001629e-06
# 226 SNES Function norm 2.246433631347e-06
# 227 SNES Function norm 2.224437248201e-06
# 228 SNES Function norm 2.202660539257e-06
# 229 SNES Function norm 2.181101217782e-06
# 230 SNES Function norm 2.159757023379e-06
# 231 SNES Function norm 2.138625720432e-06
# 232 SNES Function norm 2.117705097534e-06
# 233 SNES Function norm 2.096992972325e-06
# 234 SNES Function norm 2.076487183507e-06
# 235 SNES Function norm 2.056185594924e-06
# 236 SNES Function norm 2.036086093885e-06
# 237 SNES Function norm 2.016186591578e-06
# 238 SNES Function norm 1.996485022260e-06
# 239 SNES Function norm 1.976979341365e-06
# 240 SNES Function norm 1.957667532786e-06
# 241 SNES Function norm 1.938547603163e-06
# 242 SNES Function norm 1.919617570836e-06
# 243 SNES Function norm 1.900875479580e-06
# 244 SNES Function norm 1.882319402713e-06
# 245 SNES Function norm 1.863947430535e-06
# 246 SNES Function norm 1.845757668842e-06
# 247 SNES Function norm 1.827748253806e-06
# 248 SNES Function norm 1.809917336263e-06
# 249 SNES Function norm 1.792263088176e-06
# 250 SNES Function norm 1.774783700355e-06
# 251 SNES Function norm 1.757477388768e-06
# 252 SNES Function norm 1.740342380782e-06
# 253 SNES Function norm 1.723376927612e-06
# 254 SNES Function norm 1.706579299329e-06
# 255 SNES Function norm 1.689947784361e-06
# 256 SNES Function norm 1.673480690180e-06
# 257 SNES Function norm 1.657176342102e-06
# 258 SNES Function norm 1.641033083784e-06
# 259 SNES Function norm 1.625049276537e-06
# 260 SNES Function norm 1.609223299670e-06
# 261 SNES Function norm 1.593553549716e-06
# 262 SNES Function norm 1.578038440700e-06
# 263 SNES Function norm 1.562676403216e-06
# 264 SNES Function norm 1.547465885531e-06
# 265 SNES Function norm 1.532405353563e-06
# 266 SNES Function norm 1.517493282170e-06
# 267 SNES Function norm 1.502728174260e-06
# 268 SNES Function norm 1.488108541947e-06
# 269 SNES Function norm 1.473632914053e-06
# 270 SNES Function norm 1.459299834988e-06
# 271 SNES Function norm 1.445107865231e-06
# 272 SNES Function norm 1.431055580088e-06
# 273 SNES Function norm 1.417141570151e-06
# 274 SNES Function norm 1.403364441112e-06
# 275 SNES Function norm 1.389722813504e-06
# 276 SNES Function norm 1.376215322116e-06
# 277 SNES Function norm 1.362840616380e-06
# 278 SNES Function norm 1.349597360331e-06
# 279 SNES Function norm 1.336484231391e-06
# 280 SNES Function norm 1.323499921664e-06
# 281 SNES Function norm 1.310643136418e-06
# 282 SNES Function norm 1.297912594921e-06
# 283 SNES Function norm 1.285307029880e-06
# 284 SNES Function norm 1.272825187109e-06
# 285 SNES Function norm 1.260465825958e-06
# 286 SNES Function norm 1.248227717951e-06
# 287 SNES Function norm 1.236109648407e-06
# 288 SNES Function norm 1.224110417058e-06
# 289 SNES Function norm 1.212228828945e-06
# 290 SNES Function norm 1.200463710707e-06
# 291 SNES Function norm 1.188813896819e-06
# 292 SNES Function norm 1.177278234011e-06
# 293 SNES Function norm 1.165855581217e-06
# 294 SNES Function norm 1.154544809645e-06
# 295 SNES Function norm 1.143344802090e-06
# 296 SNES Function norm 1.132254452459e-06
# 297 SNES Function norm 1.121272666866e-06
# 298 SNES Function norm 1.110398362257e-06
# 299 SNES Function norm 1.099630467184e-06
# 300 SNES Function norm 1.088967920883e-06
# 301 SNES Function norm 1.078409673910e-06
# 302 SNES Function norm 1.067954687623e-06
# 303 SNES Function norm 1.057601933666e-06
# 304 SNES Function norm 1.047350395114e-06
# 305 SNES Function norm 1.037199064796e-06
# 306 SNES Function norm 1.027146946215e-06
# 307 SNES Function norm 1.017193053162e-06
# 308 SNES Function norm 1.007336409598e-06
# 309 SNES Function norm 9.975760492685e-07
# 310 SNES Function norm 9.879110161444e-07
# 311 SNES Function norm 9.783403639450e-07
# 312 SNES Function norm 9.688631560109e-07
# 313 SNES Function norm 9.594784650537e-07
# 314 SNES Function norm 9.501853739559e-07
# 315 SNES Function norm 9.409829745915e-07
# 316 SNES Function norm 9.318703679904e-07
# 317 SNES Function norm 9.228466644270e-07
# 318 SNES Function norm 9.139109834055e-07
# 319 SNES Function norm 9.050624535440e-07
# 320 SNES Function norm 8.963002098852e-07
# 321 SNES Function norm 8.876234039734e-07
# 322 SNES Function norm 8.790311865445e-07
# 323 SNES Function norm 8.705227218828e-07
# 324 SNES Function norm 8.620971818164e-07
# 325 SNES Function norm 8.537537469748e-07
# 326 SNES Function norm 8.454916060298e-07
# 327 SNES Function norm 8.373099560341e-07
# 328 SNES Function norm 8.292080020945e-07
# 329 SNES Function norm 8.211849574089e-07
# 330 SNES Function norm 8.132400429642e-07
# 331 SNES Function norm 8.053724882755e-07
# 332 SNES Function norm 7.975815297264e-07
# 333 SNES Function norm 7.898664122950e-07
# 334 SNES Function norm 7.822263880816e-07
# 335 SNES Function norm 7.746607171241e-07
# 336 SNES Function norm 7.671686663620e-07
# 337 SNES Function norm 7.597495106628e-07
# 338 SNES Function norm 7.524025324098e-07
# 339 SNES Function norm 7.451270201642e-07
# 340 SNES Function norm 7.379222712402e-07
# 341 SNES Function norm 7.307875885663e-07
# 342 SNES Function norm 7.237222830366e-07
# 343 SNES Function norm 7.167256714066e-07
# 344 SNES Function norm 7.097970823194e-07
# 345 SNES Function norm 7.029358414478e-07
# 346 SNES Function norm 6.961412877835e-07
# 347 SNES Function norm 6.894127666328e-07
# 348 SNES Function norm 6.827496291422e-07
# 349 SNES Function norm 6.761512333143e-07
# 350 SNES Function norm 6.696169429986e-07
# 351 SNES Function norm 6.631461289205e-07
# 352 SNES Function norm 6.567381680596e-07
# 353 SNES Function norm 6.503924431435e-07
# 354 SNES Function norm 6.441083435987e-07
# 355 SNES Function norm 6.378852649067e-07
# 356 SNES Function norm 6.317226084560e-07
# 357 SNES Function norm 6.256197817792e-07
# 358 SNES Function norm 6.195761979811e-07
# 359 SNES Function norm 6.135912765389e-07
# 360 SNES Function norm 6.076644424871e-07
# 361 SNES Function norm 6.017951263923e-07
# 362 SNES Function norm 5.959827649082e-07
# 363 SNES Function norm 5.902268001414e-07
# 364 SNES Function norm 5.845266796680e-07
# 365 SNES Function norm 5.788818562019e-07
# 366 SNES Function norm 5.732917913951e-07
# 367 SNES Function norm 5.677559455634e-07
# 368 SNES Function norm 5.622737890130e-07
# 369 SNES Function norm 5.568447963073e-07
# 370 SNES Function norm 5.514684479318e-07
# 371 SNES Function norm 5.461442287742e-07
# 372 SNES Function norm 5.408716289578e-07
# 373 SNES Function norm 5.356501437777e-07
# 374 SNES Function norm 5.304792738369e-07
# 375 SNES Function norm 5.253585241205e-07
# 376 SNES Function norm 5.202874048337e-07
# 377 SNES Function norm 5.152654311299e-07
# 378 SNES Function norm 5.102921229476e-07
# 379 SNES Function norm 5.053670044401e-07
# 380 SNES Function norm 5.004896054824e-07
# 381 SNES Function norm 4.956594599295e-07
# 382 SNES Function norm 4.908761063862e-07
# 383 SNES Function norm 4.861390882654e-07
# 384 SNES Function norm 4.814479528351e-07
# 385 SNES Function norm 4.768022529391e-07
# 386 SNES Function norm 4.722015447981e-07
# 387 SNES Function norm 4.676453896771e-07
# 388 SNES Function norm 4.631333530403e-07
# 389 SNES Function norm 4.586650042210e-07
# 390 SNES Function norm 4.542399175924e-07
# 391 SNES Function norm 4.498576712613e-07
# 392 SNES Function norm 4.455178474364e-07
# 393 SNES Function norm 4.412200325409e-07
# 394 SNES Function norm 4.369638172970e-07
# 395 SNES Function norm 4.327487963724e-07
# 396 SNES Function norm 4.285745680368e-07
# 397 SNES Function norm 4.244407353207e-07
# 398 SNES Function norm 4.203469045574e-07
# 399 SNES Function norm 4.162926861048e-07
# 400 SNES Function norm 4.122776940700e-07
# 401 SNES Function norm 4.083015468397e-07
# 402 SNES Function norm 4.043638658278e-07
# 403 SNES Function norm 4.004642766399e-07
# 404 SNES Function norm 3.966024086593e-07
# 405 SNES Function norm 3.927778949124e-07
# 406 SNES Function norm 3.889903716505e-07
# 407 SNES Function norm 3.852394787866e-07
# 408 SNES Function norm 3.815248603046e-07
# 409 SNES Function norm 3.778461631518e-07
# 410 SNES Function norm 3.742030379756e-07
# 411 SNES Function norm 3.705951388636e-07
# 412 SNES Function norm 3.670221231395e-07
# 413 SNES Function norm 3.634836516824e-07
# 414 SNES Function norm 3.599793886356e-07
# 415 SNES Function norm 3.565090014739e-07
# 416 SNES Function norm 3.530721610792e-07
# 417 SNES Function norm 3.496685411577e-07
# 418 SNES Function norm 3.462978188361e-07
# 419 SNES Function norm 3.429596746913e-07
# 420 SNES Function norm 3.396537920844e-07
# 421 SNES Function norm 3.363798575478e-07
# 422 SNES Function norm 3.331375608049e-07
# 423 SNES Function norm 3.299265944471e-07
# 424 SNES Function norm 3.267466545344e-07
# 425 SNES Function norm 3.235974392682e-07
# 426 SNES Function norm 3.204786506216e-07
# 427 SNES Function norm 3.173899930797e-07
# 428 SNES Function norm 3.143311743169e-07
# 429 SNES Function norm 3.113019044223e-07
# 430 SNES Function norm 3.083018967314e-07
# 431 SNES Function norm 3.053308664503e-07
# 432 SNES Function norm 3.023885348015e-07
# 433 SNES Function norm 2.994746210970e-07
# 434 SNES Function norm 2.965888498763e-07
# 435 SNES Function norm 2.937309482450e-07
# 436 SNES Function norm 2.909006459688e-07
# 437 SNES Function norm 2.880976752968e-07
# 438 SNES Function norm 2.853217712365e-07
# 439 SNES Function norm 2.825726709878e-07
# 440 SNES Function norm 2.798501150868e-07
# 441 SNES Function norm 2.771538457801e-07
# 442 SNES Function norm 2.744836083502e-07
# 443 SNES Function norm 2.718391503375e-07
# 444 SNES Function norm 2.692202221092e-07
# 445 SNES Function norm 2.666265754636e-07
# 446 SNES Function norm 2.640579661646e-07
# 447 SNES Function norm 2.615141511315e-07
# 448 SNES Function norm 2.589948899616e-07
# 449 SNES Function norm 2.564999451590e-07
# 450 SNES Function norm 2.540290808322e-07
# 451 SNES Function norm 2.515820637221e-07
# 452 SNES Function norm 2.491586627331e-07
# 453 SNES Function norm 2.467586490357e-07
# 454 SNES Function norm 2.443817962404e-07
# 455 SNES Function norm 2.420278799154e-07
# 456 SNES Function norm 2.396966778584e-07
# 457 SNES Function norm 2.373879702658e-07
# 458 SNES Function norm 2.351015390957e-07
# 459 SNES Function norm 2.328371688444e-07
# 460 SNES Function norm 2.305946457202e-07
# 461 SNES Function norm 2.283737582327e-07
# 462 SNES Function norm 2.261742970463e-07
# 463 SNES Function norm 2.239960545749e-07
# 464 SNES Function norm 2.218388255356e-07
# 465 SNES Function norm 2.197024064932e-07
# 466 SNES Function norm 2.175865960004e-07
# 467 SNES Function norm 2.154911947161e-07
# 468 SNES Function norm 2.134160050305e-07
# 469 SNES Function norm 2.113608314581e-07
# 470 SNES Function norm 2.093254801228e-07
# 471 SNES Function norm 2.073097594458e-07
# 472 SNES Function norm 2.053134793239e-07
# 473 SNES Function norm 2.033364517264e-07
# 474 SNES Function norm 2.013784906466e-07
# 475 SNES Function norm 1.994394113382e-07
# 476 SNES Function norm 1.975190312153e-07
# 477 SNES Function norm 1.956171696515e-07
# 478 SNES Function norm 1.937336471917e-07
# 479 SNES Function norm 1.918682867409e-07
# 480 SNES Function norm 1.900209125382e-07
# 481 SNES Function norm 1.881913507695e-07
# 482 SNES Function norm 1.863794290398e-07
# 483 SNES Function norm 1.845849769330e-07
# 484 SNES Function norm 1.828078255006e-07
# 485 SNES Function norm 1.810478074858e-07
# 486 SNES Function norm 1.793047571611e-07
# 487 SNES Function norm 1.775785106592e-07
# 488 SNES Function norm 1.758689054456e-07
# 489 SNES Function norm 1.741757808667e-07
# 490 SNES Function norm 1.724989761168e-07
# 491 SNES Function norm 1.708383375826e-07
# 492 SNES Function norm 1.691937051908e-07
# 493 SNES Function norm 1.675649250396e-07
# 494 SNES Function norm 1.659518442180e-07
# 495 SNES Function norm 1.643543110076e-07
# 496 SNES Function norm 1.627721757017e-07
# 497 SNES Function norm 1.612052882282e-07
# 498 SNES Function norm 1.596535028350e-07
# 499 SNES Function norm 1.581166726018e-07
# 500 SNES Function norm 1.565946533941e-07
#
#  Increment: 20, load = 0.0011347817974536106
#   0 SNES Function norm 1.021430932885e-05
#   1 SNES Function norm 2.912109190820e-05
#   2 SNES Function norm 2.887773825852e-05
#   3 SNES Function norm 2.860600080478e-05
#   4 SNES Function norm 2.832731721082e-05
#   5 SNES Function norm 2.804898137821e-05
#   6 SNES Function norm 2.777327409409e-05
#   7 SNES Function norm 2.750088420499e-05
#   8 SNES Function norm 2.723199538780e-05
#   9 SNES Function norm 2.696662488014e-05
#  10 SNES Function norm 2.670473148925e-05
#  11 SNES Function norm 2.644625187576e-05
#  12 SNES Function norm 2.619111392132e-05
#  13 SNES Function norm 2.593924226420e-05
#  14 SNES Function norm 2.569056096954e-05
#  15 SNES Function norm 2.544499493024e-05
#  16 SNES Function norm 2.520247068813e-05
#  17 SNES Function norm 2.496291691466e-05
#  18 SNES Function norm 2.472626466695e-05
#  19 SNES Function norm 2.449244752439e-05
#  20 SNES Function norm 2.426140163949e-05
#  21 SNES Function norm 2.403306571640e-05
#  22 SNES Function norm 2.380738097279e-05
#  23 SNES Function norm 2.358429105238e-05
#  24 SNES Function norm 2.336374195269e-05
#  25 SNES Function norm 2.314568187883e-05
#  26 SNES Function norm 2.293006122645e-05
#  27 SNES Function norm 2.271683238321e-05
#  28 SNES Function norm 2.250594963156e-05
#  29 SNES Function norm 2.229736913744e-05
#  30 SNES Function norm 2.209104874549e-05
#  31 SNES Function norm 2.188694795595e-05
#  32 SNES Function norm 2.168502777386e-05
#  33 SNES Function norm 2.148525066326e-05
#  34 SNES Function norm 2.128758046573e-05
#  35 SNES Function norm 2.109198228997e-05
#  36 SNES Function norm 2.089842249128e-05
#  37 SNES Function norm 2.070686855967e-05
#  38 SNES Function norm 2.051728904759e-05
#  39 SNES Function norm 2.032965359207e-05
#  40 SNES Function norm 2.014393276596e-05
#  41 SNES Function norm 1.996009805641e-05
#  42 SNES Function norm 1.977812183514e-05
#  43 SNES Function norm 1.959797728659e-05
#  44 SNES Function norm 1.941963838730e-05
#  45 SNES Function norm 1.924307984666e-05
#  46 SNES Function norm 1.906827710362e-05
#  47 SNES Function norm 1.889520624250e-05
#  48 SNES Function norm 1.872384393010e-05
#  49 SNES Function norm 1.855416754225e-05
#  50 SNES Function norm 1.838615498398e-05
#  51 SNES Function norm 1.821978471769e-05
#  52 SNES Function norm 1.805503570398e-05
#  53 SNES Function norm 1.789188742332e-05
#  54 SNES Function norm 1.773031986753e-05
#  55 SNES Function norm 1.757031342510e-05
#  56 SNES Function norm 1.741184895460e-05
#  57 SNES Function norm 1.725490773527e-05
#  58 SNES Function norm 1.709947143987e-05
#  59 SNES Function norm 1.694552213492e-05
#  60 SNES Function norm 1.679304225153e-05
#  61 SNES Function norm 1.664201457220e-05
#  62 SNES Function norm 1.649242222280e-05
#  63 SNES Function norm 1.634424866673e-05
#  64 SNES Function norm 1.619747767713e-05
#  65 SNES Function norm 1.605209333260e-05
#  66 SNES Function norm 1.590808000252e-05
#  67 SNES Function norm 1.576542234845e-05
#  68 SNES Function norm 1.562410529455e-05
#  69 SNES Function norm 1.548411403404e-05
#  70 SNES Function norm 1.534543401570e-05
#  71 SNES Function norm 1.520805094575e-05
#  72 SNES Function norm 1.507195074281e-05
#  73 SNES Function norm 1.493711958388e-05
#  74 SNES Function norm 1.480354385516e-05
#  75 SNES Function norm 1.467121016888e-05
#  76 SNES Function norm 1.454010533573e-05
#  77 SNES Function norm 1.441021638925e-05
#  78 SNES Function norm 1.428153054404e-05
#  79 SNES Function norm 1.415403521950e-05
#  80 SNES Function norm 1.402771801660e-05
#  81 SNES Function norm 1.390256672126e-05
#  82 SNES Function norm 1.377856930213e-05
#  83 SNES Function norm 1.365571388725e-05
#  84 SNES Function norm 1.353398878633e-05
#  85 SNES Function norm 1.341338246876e-05
#  86 SNES Function norm 1.329388355937e-05
#  87 SNES Function norm 1.317548085027e-05
#  88 SNES Function norm 1.305816327755e-05
#  89 SNES Function norm 1.294191992109e-05
#  90 SNES Function norm 1.282674001921e-05
#  91 SNES Function norm 1.271261294129e-05
#  92 SNES Function norm 1.259952819964e-05
#  93 SNES Function norm 1.248747544201e-05
#  94 SNES Function norm 1.237644444969e-05
#  95 SNES Function norm 1.226642513132e-05
#  96 SNES Function norm 1.215740752332e-05
#  97 SNES Function norm 1.204938178687e-05
#  98 SNES Function norm 1.194233820804e-05
#  99 SNES Function norm 1.183626718375e-05
# 100 SNES Function norm 1.173115923483e-05
# 101 SNES Function norm 1.162700499473e-05
# 102 SNES Function norm 1.152379520909e-05
# 103 SNES Function norm 1.142152073313e-05
# 104 SNES Function norm 1.132017253390e-05
# 105 SNES Function norm 1.121974167802e-05
# 106 SNES Function norm 1.112021934067e-05
# 107 SNES Function norm 1.102159679940e-05
# 108 SNES Function norm 1.092386542999e-05
# 109 SNES Function norm 1.082701670855e-05
# 110 SNES Function norm 1.073104220931e-05
# 111 SNES Function norm 1.063593359475e-05
# 112 SNES Function norm 1.054168263126e-05
# 113 SNES Function norm 1.044828117418e-05
# 114 SNES Function norm 1.035572116248e-05
# 115 SNES Function norm 1.026399463438e-05
# 116 SNES Function norm 1.017309370873e-05
# 117 SNES Function norm 1.008301058617e-05
# 118 SNES Function norm 9.993737569113e-06
# 119 SNES Function norm 9.905267036680e-06
# 120 SNES Function norm 9.817591437293e-06
# 121 SNES Function norm 9.730703314645e-06
# 122 SNES Function norm 9.644595287262e-06
# 123 SNES Function norm 9.559260046908e-06
# 124 SNES Function norm 9.474690373406e-06
# 125 SNES Function norm 9.390879119786e-06
# 126 SNES Function norm 9.307819211556e-06
# 127 SNES Function norm 9.225503649864e-06
# 128 SNES Function norm 9.143925532140e-06
# 129 SNES Function norm 9.063077927056e-06
# 130 SNES Function norm 8.982954137041e-06
# 131 SNES Function norm 8.903547414746e-06
# 132 SNES Function norm 8.824851121361e-06
# 133 SNES Function norm 8.746858677460e-06
# 134 SNES Function norm 8.669563573977e-06
# 135 SNES Function norm 8.592959372583e-06
# 136 SNES Function norm 8.517039696136e-06
# 137 SNES Function norm 8.441798235986e-06
# 138 SNES Function norm 8.367228739430e-06
# 139 SNES Function norm 8.293325014861e-06
# 140 SNES Function norm 8.220080953431e-06
# 141 SNES Function norm 8.147490486444e-06
# 142 SNES Function norm 8.075547613885e-06
# 143 SNES Function norm 8.004246453421e-06
# 144 SNES Function norm 7.933580923140e-06
# 145 SNES Function norm 7.863545438307e-06
# 146 SNES Function norm 7.794134127523e-06
# 147 SNES Function norm 7.725341281751e-06
# 148 SNES Function norm 7.657161256550e-06
# 149 SNES Function norm 7.589588456896e-06
# 150 SNES Function norm 7.522617338733e-06
# 151 SNES Function norm 7.456242407514e-06
# 152 SNES Function norm 7.390458239760e-06
# 153 SNES Function norm 7.325259447940e-06
# 154 SNES Function norm 7.260640704075e-06
# 155 SNES Function norm 7.196596728471e-06
# 156 SNES Function norm 7.133122298746e-06
# 157 SNES Function norm 7.070212237521e-06
# 158 SNES Function norm 7.007861419190e-06
# 159 SNES Function norm 6.946064767411e-06
# 160 SNES Function norm 6.884817254622e-06
# 161 SNES Function norm 6.824113903052e-06
# 162 SNES Function norm 6.763949778002e-06
# 163 SNES Function norm 6.704319996689e-06
# 164 SNES Function norm 6.645219722473e-06
# 165 SNES Function norm 6.586644164940e-06
# 166 SNES Function norm 6.528588577979e-06
# 167 SNES Function norm 6.471048326366e-06
# 168 SNES Function norm 6.414018529213e-06
# 169 SNES Function norm 6.357494846046e-06
# 170 SNES Function norm 6.301472585136e-06
# 171 SNES Function norm 6.245947229755e-06
# 172 SNES Function norm 6.190914300149e-06
# 173 SNES Function norm 6.136369358431e-06
# 174 SNES Function norm 6.082308006371e-06
# 175 SNES Function norm 6.028725888212e-06
# 176 SNES Function norm 5.975618689173e-06
# 177 SNES Function norm 5.922982133283e-06
# 178 SNES Function norm 5.870811984341e-06
# 179 SNES Function norm 5.819104050078e-06
# 180 SNES Function norm 5.767854175947e-06
# 181 SNES Function norm 5.717058241505e-06
# 182 SNES Function norm 5.666712170078e-06
# 183 SNES Function norm 5.616811921111e-06
# 184 SNES Function norm 5.567353492016e-06
# 185 SNES Function norm 5.518332916990e-06
# 186 SNES Function norm 5.469746267724e-06
# 187 SNES Function norm 5.421589651810e-06
# 188 SNES Function norm 5.373859213698e-06
# 189 SNES Function norm 5.326551133342e-06
# 190 SNES Function norm 5.279661625574e-06
# 191 SNES Function norm 5.233186941562e-06
# 192 SNES Function norm 5.187123365554e-06
# 193 SNES Function norm 5.141467217062e-06
# 194 SNES Function norm 5.096214849617e-06
# 195 SNES Function norm 5.051362650261e-06
# 196 SNES Function norm 5.006907039287e-06
# 197 SNES Function norm 4.962844470146e-06
# 198 SNES Function norm 4.919171428642e-06
# 199 SNES Function norm 4.875884433581e-06
# 200 SNES Function norm 4.832980034847e-06
# 201 SNES Function norm 4.790454814823e-06
# 202 SNES Function norm 4.748305386764e-06
# 203 SNES Function norm 4.706528395185e-06
# 204 SNES Function norm 4.665120515672e-06
# 205 SNES Function norm 4.624078453387e-06
# 206 SNES Function norm 4.583398944643e-06
# 207 SNES Function norm 4.543078755897e-06
# 208 SNES Function norm 4.503114681013e-06
# 209 SNES Function norm 4.463503545400e-06
# 210 SNES Function norm 4.424242202602e-06
# 211 SNES Function norm 4.385327535077e-06
# 212 SNES Function norm 4.346756452927e-06
# 213 SNES Function norm 4.308525897142e-06
# 214 SNES Function norm 4.270632832914e-06
# 215 SNES Function norm 4.233074254655e-06
# 216 SNES Function norm 4.195847184490e-06
# 217 SNES Function norm 4.158948671472e-06
# 218 SNES Function norm 4.122375791465e-06
# 219 SNES Function norm 4.086125646820e-06
# 220 SNES Function norm 4.050195366184e-06
# 221 SNES Function norm 4.014582104042e-06
# 222 SNES Function norm 3.979283041265e-06
# 223 SNES Function norm 3.944295383887e-06
# 224 SNES Function norm 3.909616363173e-06
# 225 SNES Function norm 3.875243235831e-06
# 226 SNES Function norm 3.841173283319e-06
# 227 SNES Function norm 3.807403811454e-06
# 228 SNES Function norm 3.773932150861e-06
# 229 SNES Function norm 3.740755655981e-06
# 230 SNES Function norm 3.707871705049e-06
# 231 SNES Function norm 3.675277700591e-06
# 232 SNES Function norm 3.642971067895e-06
# 233 SNES Function norm 3.610949255896e-06
# 234 SNES Function norm 3.579209736544e-06
# 235 SNES Function norm 3.547750004390e-06
# 236 SNES Function norm 3.516567577814e-06
# 237 SNES Function norm 3.485659995023e-06
# 238 SNES Function norm 3.455024818199e-06
# 239 SNES Function norm 3.424659631195e-06
# 240 SNES Function norm 3.394562040320e-06
# 241 SNES Function norm 3.364729670736e-06
# 242 SNES Function norm 3.335160173023e-06
# 243 SNES Function norm 3.305851216135e-06
# 244 SNES Function norm 3.276800490706e-06
# 245 SNES Function norm 3.248005708184e-06
# 246 SNES Function norm 3.219464600514e-06
# 247 SNES Function norm 3.191174919731e-06
# 248 SNES Function norm 3.163134438710e-06
# 249 SNES Function norm 3.135340949575e-06
# 250 SNES Function norm 3.107792264955e-06
# 251 SNES Function norm 3.080486216646e-06
# 252 SNES Function norm 3.053420656385e-06
# 253 SNES Function norm 3.026593454277e-06
# 254 SNES Function norm 3.000002500643e-06
# 255 SNES Function norm 2.973645703654e-06
# 256 SNES Function norm 2.947520991186e-06
# 257 SNES Function norm 2.921626308979e-06
# 258 SNES Function norm 2.895959621314e-06
# 259 SNES Function norm 2.870518911234e-06
# 260 SNES Function norm 2.845302179176e-06
# 261 SNES Function norm 2.820307443497e-06
# 262 SNES Function norm 2.795532740643e-06
# 263 SNES Function norm 2.770976124662e-06
# 264 SNES Function norm 2.746635666583e-06
# 265 SNES Function norm 2.722509455042e-06
# 266 SNES Function norm 2.698595595498e-06
# 267 SNES Function norm 2.674892210513e-06
# 268 SNES Function norm 2.651397439452e-06
# 269 SNES Function norm 2.628109438075e-06
# 270 SNES Function norm 2.605026378959e-06
# 271 SNES Function norm 2.582146450497e-06
# 272 SNES Function norm 2.559467857676e-06
# 273 SNES Function norm 2.536988821648e-06
# 274 SNES Function norm 2.514707578979e-06
# 275 SNES Function norm 2.492622381891e-06
# 276 SNES Function norm 2.470731498914e-06
# 277 SNES Function norm 2.449033213083e-06
# 278 SNES Function norm 2.427525823425e-06
# 279 SNES Function norm 2.406207644074e-06
# 280 SNES Function norm 2.385077003863e-06
# 281 SNES Function norm 2.364132246769e-06
# 282 SNES Function norm 2.343371731122e-06
# 283 SNES Function norm 2.322793830371e-06
# 284 SNES Function norm 2.302396932532e-06
# 285 SNES Function norm 2.282179439371e-06
# 286 SNES Function norm 2.262139767139e-06
# 287 SNES Function norm 2.242276346659e-06
# 288 SNES Function norm 2.222587621776e-06
# 289 SNES Function norm 2.203072051191e-06
# 290 SNES Function norm 2.183728106478e-06
# 291 SNES Function norm 2.164554273318e-06
# 292 SNES Function norm 2.145549050733e-06
# 293 SNES Function norm 2.126710950927e-06
# 294 SNES Function norm 2.108038499493e-06
# 295 SNES Function norm 2.089530235382e-06
# 296 SNES Function norm 2.071184709864e-06
# 297 SNES Function norm 2.053000487537e-06
# 298 SNES Function norm 2.034976145779e-06
# 299 SNES Function norm 2.017110274181e-06
# 300 SNES Function norm 1.999401475848e-06
# 301 SNES Function norm 1.981848365116e-06
# 302 SNES Function norm 1.964449569107e-06
# 303 SNES Function norm 1.947203727462e-06
# 304 SNES Function norm 1.930109491169e-06
# 305 SNES Function norm 1.913165523899e-06
# 306 SNES Function norm 1.896370500702e-06
# 307 SNES Function norm 1.879723108587e-06
# 308 SNES Function norm 1.863222046598e-06
# 309 SNES Function norm 1.846866024405e-06
# 310 SNES Function norm 1.830653763748e-06
# 311 SNES Function norm 1.814583997660e-06
# 312 SNES Function norm 1.798655468975e-06
# 313 SNES Function norm 1.782866935842e-06
# 314 SNES Function norm 1.767217163124e-06
# 315 SNES Function norm 1.751704927704e-06
# 316 SNES Function norm 1.736329018415e-06
# 317 SNES Function norm 1.721088233922e-06
# 318 SNES Function norm 1.705981383475e-06
# 319 SNES Function norm 1.691007287503e-06
# 320 SNES Function norm 1.676164776127e-06
# 321 SNES Function norm 1.661452690371e-06
# 322 SNES Function norm 1.646869881678e-06
# 323 SNES Function norm 1.632415210647e-06
# 324 SNES Function norm 1.618087549291e-06
# 325 SNES Function norm 1.603885778834e-06
# 326 SNES Function norm 1.589808790444e-06
# 327 SNES Function norm 1.575855485248e-06
# 328 SNES Function norm 1.562024774057e-06
# 329 SNES Function norm 1.548315577530e-06
# 330 SNES Function norm 1.534726825614e-06
# 331 SNES Function norm 1.521257457297e-06
# 332 SNES Function norm 1.507906422246e-06
# 333 SNES Function norm 1.494672678158e-06
# 334 SNES Function norm 1.481555191394e-06
# 335 SNES Function norm 1.468552941771e-06
# 336 SNES Function norm 1.455664911987e-06
# 337 SNES Function norm 1.442890096823e-06
# 338 SNES Function norm 1.430227499839e-06
# 339 SNES Function norm 1.417676134015e-06
# 340 SNES Function norm 1.405235019408e-06
# 341 SNES Function norm 1.392903186261e-06
# 342 SNES Function norm 1.380679672529e-06
# 343 SNES Function norm 1.368563525246e-06
# 344 SNES Function norm 1.356553799002e-06
# 345 SNES Function norm 1.344649557583e-06
# 346 SNES Function norm 1.332849872926e-06
# 347 SNES Function norm 1.321153824509e-06
# 348 SNES Function norm 1.309560500764e-06
# 349 SNES Function norm 1.298068997904e-06
# 350 SNES Function norm 1.286678419714e-06
# 351 SNES Function norm 1.275387878446e-06
# 352 SNES Function norm 1.264196494019e-06
# 353 SNES Function norm 1.253103393773e-06
# 354 SNES Function norm 1.242107713499e-06
# 355 SNES Function norm 1.231208595916e-06
# 356 SNES Function norm 1.220405191703e-06
# 357 SNES Function norm 1.209696658893e-06
# 358 SNES Function norm 1.199082162756e-06
# 359 SNES Function norm 1.188560876364e-06
# 360 SNES Function norm 1.178131979842e-06
# 361 SNES Function norm 1.167794660656e-06
# 362 SNES Function norm 1.157548113337e-06
# 363 SNES Function norm 1.147391539422e-06
# 364 SNES Function norm 1.137324147826e-06
# 365 SNES Function norm 1.127345153875e-06
# 366 SNES Function norm 1.117453780669e-06
# 367 SNES Function norm 1.107649257486e-06
# 368 SNES Function norm 1.097930820523e-06
# 369 SNES Function norm 1.088297712802e-06
# 370 SNES Function norm 1.078749184245e-06
# 371 SNES Function norm 1.069284490943e-06
# 372 SNES Function norm 1.059902895572e-06
# 373 SNES Function norm 1.050603667928e-06
# 374 SNES Function norm 1.041386084016e-06
# 375 SNES Function norm 1.032249425102e-06
# 376 SNES Function norm 1.023192980416e-06
# 377 SNES Function norm 1.014216044623e-06
# 378 SNES Function norm 1.005317918893e-06
# 379 SNES Function norm 9.964979101051e-07
# 380 SNES Function norm 9.877553316674e-07
# 381 SNES Function norm 9.790895029317e-07
# 382 SNES Function norm 9.704997492913e-07
# 383 SNES Function norm 9.619854020834e-07
# 384 SNES Function norm 9.535457984743e-07
# 385 SNES Function norm 9.451802811742e-07
# 386 SNES Function norm 9.368881994484e-07
# 387 SNES Function norm 9.286689088727e-07
# 388 SNES Function norm 9.205217656981e-07
# 389 SNES Function norm 9.124461399405e-07
# 390 SNES Function norm 9.044414015838e-07
# 391 SNES Function norm 8.965069281733e-07
# 392 SNES Function norm 8.886421018701e-07
# 393 SNES Function norm 8.808463103758e-07
# 394 SNES Function norm 8.731189472735e-07
# 395 SNES Function norm 8.654594112822e-07
# 396 SNES Function norm 8.578671058476e-07
# 397 SNES Function norm 8.503414409041e-07
# 398 SNES Function norm 8.428818305071e-07
# 399 SNES Function norm 8.354876940771e-07
# 400 SNES Function norm 8.281584568370e-07
# 401 SNES Function norm 8.208935479363e-07
# 402 SNES Function norm 8.136924025080e-07
# 403 SNES Function norm 8.065544602692e-07
# 404 SNES Function norm 7.994791658667e-07
# 405 SNES Function norm 7.924659688282e-07
# 406 SNES Function norm 7.855143238814e-07
# 407 SNES Function norm 7.786236896150e-07
# 408 SNES Function norm 7.717935310182e-07
# 409 SNES Function norm 7.650233156853e-07
# 410 SNES Function norm 7.583125177709e-07
# 411 SNES Function norm 7.516606150198e-07
# 412 SNES Function norm 7.450670902439e-07
# 413 SNES Function norm 7.385314302291e-07
# 414 SNES Function norm 7.320531272786e-07
# 415 SNES Function norm 7.256316765703e-07
# 416 SNES Function norm 7.192665800333e-07
# 417 SNES Function norm 7.129573416230e-07
# 418 SNES Function norm 7.067034710653e-07
# 419 SNES Function norm 7.005044819142e-07
# 420 SNES Function norm 6.943598920722e-07
# 421 SNES Function norm 6.882692239544e-07
# 422 SNES Function norm 6.822320037669e-07
# 423 SNES Function norm 6.762477621562e-07
# 424 SNES Function norm 6.703160338644e-07
# 425 SNES Function norm 6.644363577492e-07
# 426 SNES Function norm 6.586082762231e-07
# 427 SNES Function norm 6.528313363642e-07
# 428 SNES Function norm 6.471050894249e-07
# 429 SNES Function norm 6.414290897194e-07
# 430 SNES Function norm 6.358028962314e-07
# 431 SNES Function norm 6.302260713346e-07
# 432 SNES Function norm 6.246981818367e-07
# 433 SNES Function norm 6.192187974667e-07
# 434 SNES Function norm 6.137874927848e-07
# 435 SNES Function norm 6.084038451740e-07
# 436 SNES Function norm 6.030674367497e-07
# 437 SNES Function norm 5.977778518313e-07
# 438 SNES Function norm 5.925346800869e-07
# 439 SNES Function norm 5.873375131443e-07
# 440 SNES Function norm 5.821859479027e-07
# 441 SNES Function norm 5.770795832967e-07
# 442 SNES Function norm 5.720180227948e-07
# 443 SNES Function norm 5.670008728013e-07
# 444 SNES Function norm 5.620277433945e-07
# 445 SNES Function norm 5.570982481320e-07
# 446 SNES Function norm 5.522120039519e-07
# 447 SNES Function norm 5.473686309104e-07
# 448 SNES Function norm 5.425677527605e-07
# 449 SNES Function norm 5.378089962386e-07
# 450 SNES Function norm 5.330919920510e-07
# 451 SNES Function norm 5.284163727663e-07
# 452 SNES Function norm 5.237817757641e-07
# 453 SNES Function norm 5.191878405345e-07
# 454 SNES Function norm 5.146342103846e-07
# 455 SNES Function norm 5.101205310999e-07
# 456 SNES Function norm 5.056464519658e-07
# 457 SNES Function norm 5.012116257025e-07
# 458 SNES Function norm 4.968157076963e-07
# 459 SNES Function norm 4.924583558379e-07
# 460 SNES Function norm 4.881392321020e-07
# 461 SNES Function norm 4.838580007684e-07
# 462 SNES Function norm 4.796143289372e-07
# 463 SNES Function norm 4.754078874155e-07
# 464 SNES Function norm 4.712383488465e-07
# 465 SNES Function norm 4.671053896362e-07
# 466 SNES Function norm 4.630086884005e-07
# 467 SNES Function norm 4.589479272741e-07
# 468 SNES Function norm 4.549227904063e-07
# 469 SNES Function norm 4.509329651876e-07
# 470 SNES Function norm 4.469781418680e-07
# 471 SNES Function norm 4.430580128354e-07
# 472 SNES Function norm 4.391722739340e-07
# 473 SNES Function norm 4.353206231942e-07
# 474 SNES Function norm 4.315027612109e-07
# 475 SNES Function norm 4.277183916945e-07
# 476 SNES Function norm 4.239672203199e-07
# 477 SNES Function norm 4.202489562384e-07
# 478 SNES Function norm 4.165633100049e-07
# 479 SNES Function norm 4.129099959349e-07
# 480 SNES Function norm 4.092887295940e-07
# 481 SNES Function norm 4.056992303231e-07
# 482 SNES Function norm 4.021412189852e-07
# 483 SNES Function norm 3.986144192376e-07
# 484 SNES Function norm 3.951185572646e-07
# 485 SNES Function norm 3.916533614700e-07
# 486 SNES Function norm 3.882185626319e-07
# 487 SNES Function norm 3.848138942100e-07
# 488 SNES Function norm 3.814390915254e-07
# 489 SNES Function norm 3.780938928060e-07
# 490 SNES Function norm 3.747780377877e-07
# 491 SNES Function norm 3.714912691506e-07
# 492 SNES Function norm 3.682333317998e-07
# 493 SNES Function norm 3.650039724692e-07
# 494 SNES Function norm 3.618029404744e-07
# 495 SNES Function norm 3.586299872656e-07
# 496 SNES Function norm 3.554848663437e-07
# 497 SNES Function norm 3.523673335816e-07
# 498 SNES Function norm 3.492771467187e-07
# 499 SNES Function norm 3.462140659607e-07
# 500 SNES Function norm 3.431778532736e-07
#
# rank#0: Time = 321.243 (s)

# %%
if len(points_on_proc) > 0:
    import matplotlib.pyplot as plt
    plt.plot(results[:, 0], results[:, 1], "-o")
    plt.xlabel("Displacement of inner boundary")
    plt.ylabel(r"Applied pressure $q/q_{lim}$")
    plt.savefig(f"displacement_rank{MPI.COMM_WORLD.rank:d}.png")
    plt.show()
