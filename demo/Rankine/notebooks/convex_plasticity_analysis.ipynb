# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle
from pathlib import Path
import os, sys, glob

# %%
def load_one_pickle(file_path):
    try:
        with open(file_path, "rb") as f:
            return pickle.load(f)
    except EOFError:
        print(f"Skipping corrupted file: {file_path}")
        return None
import joblib 

def load_data(folder_path, n_jobs=-1):
    file_paths = glob.glob(os.path.join(folder_path, "*.pkl"))
    records = joblib.Parallel(n_jobs=n_jobs)(
        joblib.delayed(load_one_pickle)(fp) for fp in file_paths
    )
    # Remove None entries (corrupted files)
    records = [r for r in records if r is not None]
    df = pd.DataFrame(records)
    df.sort_values("date", ascending=False, inplace=True, ignore_index=True)
    return df

# %%
folder_path = Path("../output/", n_jobs=4)
main_dataframe = load_data(folder_path)
# post_process(main_dataframe)
# Out:
# /tmp/ipykernel_16629/3744007170.py:1: DeprecationWarning: support for supplying keyword arguments to pathlib.PurePath is deprecated and scheduled for removal in Python 3.14
#   folder_path = Path("../output/", n_jobs=4)

# %%
main_dataframe
# Out:
#      total_time    solver  patch_size  memory_usage  n_quadratures_local  \
# 0      3.735755  CLARABEL         288      2.562336                  288
# 1      6.345735  CLARABEL         576      1.335693                  576
# 2     13.248629  CLARABEL        1158      0.672039                 1158
# 3     10.938488  CLARABEL        1158      0.683624                 1158
# 4     35.664657     MOSEK        1158      0.791687                 1158
# 5      5.470846     MOSEK          10      0.654789                   51
# 6      3.722892     MOSEK           3      0.711563                   51
# 7      6.349953  CLARABEL         531      1.432297                  531
# 8      5.319279  CLARABEL         399      1.496826                  399
# 9      1.264866  CLARABEL           3      1.295155                   24
# 10     2.223181  CLARABEL           3      0.666302                   51
# 11     9.763804  CLARABEL          30      2.480545                  399
# 12     6.170911  CLARABEL          30      0.627075                  423
# 13     1.098780  CLARABEL          30      0.694859                   51
# 14     0.760144  CLARABEL          30      1.299564                   24
# 15    30.791244  CLARABEL           3      0.329319                  423
# 16     1.058675  CLARABEL          30      2.119038                   12
# 17     2.308764  CLARABEL           3      0.656731                   51
# 18  1571.215562  CLARABEL          30      0.827560                38391
# 19    22.105846  CLARABEL          30      0.632317                 1605
# 20     1.477048  CLARABEL          10      0.693306                   51
#
#     n_quadratures_global  n_processes  mesh_size compiled  \
# 0                   1158            4       0.06    False
# 1                   1158            2       0.06    False
# 2                   1158            1       0.06    False
# 3                   1158            1       0.06     True
# 4                   1158            1       0.06    False
# 5                     51            1       0.30    False
# 6                     51            1       0.30    False
# 7                   1605            3       0.05    False
# 8                   1605            4       0.05    False
# 9                     51            2       0.30    False
# 10                    51            1       0.30    False
# 11                  1605            4       0.05    False
# 12                   423            1       0.10      NaN
# 13                    51            1       0.30      NaN
# 14                    51            2       0.30    False
# 15                   423            1       0.10      NaN
# 16                    51            4       0.30    False
# 17                    51            1       0.30      NaN
# 18                 38391            1       0.01      NaN
# 19                  1605            1       0.05      NaN
# 20                    51            1       0.30      NaN
#
#                    date                                        output_file
# 0   2025-10-17_18-55-56   ./output/output_-CLARABEL_-288_-4_0.06_False.pkl
# 1   2025-10-17_18-49-29   ./output/output_-CLARABEL_-576_-2_0.06_False.pkl
# 2   2025-10-17_18-47-44  ./output/output_-CLARABEL_-1158_-1_0.06_False.pkl
# 3   2025-10-17_18-46-59   ./output/output_-CLARABEL_-1158_-1_0.06_True.pkl
# 4   2025-10-17_18-37-33     ./output/output_-MOSEK_-1158_-1_0.06_False.pkl
# 5   2025-10-17_18-27-41        ./output/output_-MOSEK_-10_-1_0.3_False.pkl
# 6   2025-10-17_18-26-31         ./output/output_-MOSEK_-3_-1_0.3_False.pkl
# 7   2025-10-17_18-24-13   ./output/output_-CLARABEL_-531_-3_0.05_False.pkl
# 8   2025-10-17_18-22-10   ./output/output_-CLARABEL_-399_-4_0.05_False.pkl
# 9   2025-10-17_18-21-29      ./output/output_-CLARABEL_-3_-2_0.3_False.pkl
# 10  2025-10-17_18-21-17      ./output/output_-CLARABEL_-3_-1_0.3_False.pkl
# 11                  NaN    ./output/output_-CLARABEL_-30_-4_0.05_False.pkl
# 12                  NaN           ./output/output_-CLARABEL_-30_-1_0.1.pkl
# 13                  NaN           ./output/output_-CLARABEL_-30_-1_0.3.pkl
# 14                  NaN     ./output/output_-CLARABEL_-30_-2_0.3_False.pkl
# 15                  NaN            ./output/output_-CLARABEL_-3_-1_0.1.pkl
# 16                  NaN     ./output/output_-CLARABEL_-30_-4_0.3_False.pkl
# 17                  NaN            ./output/output_-CLARABEL_-3_-1_0.3.pkl
# 18                  NaN          ./output/output_-CLARABEL_-30_-1_0.01.pkl
# 19                  NaN          ./output/output_-CLARABEL_-30_-1_0.05.pkl
# 20                  NaN           ./output/output_-CLARABEL_-10_-1_0.3.pkl
