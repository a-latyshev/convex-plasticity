# %% [markdown]
# Implementation of 2D elasto-plastic problem using FEniCS-X. The code is based on a [legacy solution](https://comet-fenics.readthedocs.io/en/latest/demo/2D_plasticity/vonMises_plasticity.py.html) for FEniCS 2019.
#
# The program was tested for 0.3.1.0 version of Dolfinx.

# %%
import meshio
import numpy as np

import ufl
from dolfinx import fem, io
from mpi4py import MPI
from petsc4py import PETSc
import time

import sys
sys.path.append("../..")
import fenicsx_support as fs
sys.path.append("../../optimisation")
import plasticity_framework as pf

# %%
if MPI.COMM_WORLD.rank == 0:

    #It works with the msh4 only!!
    msh = meshio.read("thick_cylinder_coarse.msh")

    # Create and save one file for the mesh, and one file for the facets 
    triangle_mesh = fs.create_mesh(msh, "triangle", prune_z=True)
    line_mesh = fs.create_mesh(msh, "line", prune_z=True)
    meshio.write("thick_cylinder.xdmf", triangle_mesh)
    meshio.write("mt.xdmf", line_mesh)
    print(msh)
# Out:
# <meshio mesh object>
#   Number of points: 50
#   Number of cells:
#     line: 2
#     line: 14
#     line: 2
#     line: 11
#     triangle: 69
#   Cell sets: gmsh:bounding_entities
#   Point data: gmsh:dim_tags
#   Cell data: gmsh:physical, gmsh:geometrical

# %%
with io.XDMFFile(MPI.COMM_WORLD, "thick_cylinder.xdmf", "r") as xdmf:
    mesh = xdmf.read_mesh(name="Grid")
    ct = xdmf.read_meshtags(mesh, name="Grid")

mesh.topology.create_connectivity(mesh.topology.dim, mesh.topology.dim - 1)

with io.XDMFFile(MPI.COMM_WORLD, "mt.xdmf", "r") as xdmf:
    ft = xdmf.read_meshtags(mesh, name="Grid")

# %%
# elastic parameters

sig0_dim = 70e3 #[Pa]
Ri_dim = 1.0 #[m]

E = 70e3 / sig0_dim
nu = 0.3
lmbda = E*nu/(1+nu)/(1-2*nu)
mu = E/2./(1+nu) #fem.Constant(mesh, PETSc.ScalarType(E/2./(1+nu)))
sig0 = 250 / sig0_dim #fem.Constant(mesh, PETSc.ScalarType(250 / sig0_dim))  # yield strength
Et = E/100.  # tangent modulus
H = E*Et/(E-Et)  # hardening modulus

Re, Ri = 1.3, 1.   # external/internal radius

# %%
deg_u = 2
deg_stress = 2
V = fem.VectorFunctionSpace(mesh, ("CG", deg_u))
We = ufl.VectorElement("Quadrature", mesh.ufl_cell(), degree=deg_stress, dim=4, quad_scheme='default')
W0e = ufl.FiniteElement("Quadrature", mesh.ufl_cell(), degree=deg_stress, quad_scheme='default')

W = fem.FunctionSpace(mesh, We)
W0 = fem.FunctionSpace(mesh, W0e)

# %%
sig = fem.Function(W)
sig_old = fem.Function(W)
p = fem.Function(W0)
dp = fem.Function(W0)
u = fem.Function(V, name="Total_displacement")
Du = fem.Function(V, name="Current_increment")
v = ufl.TrialFunction(V)
u_ = ufl.TestFunction(V)

P0 = fem.FunctionSpace(mesh, ("DG", 0))
p_avg = fem.Function(P0, name="Plastic_strain")

# %%
left_marker = 3
down_marker = 1
left_facets = ft.indices[ft.values == left_marker]
down_facets = ft.indices[ft.values == down_marker]
left_dofs = fem.locate_dofs_topological(V.sub(0), mesh.topology.dim-1, left_facets)
down_dofs = fem.locate_dofs_topological(V.sub(1), mesh.topology.dim-1, down_facets)

bcs = [fem.dirichletbc(PETSc.ScalarType(0), left_dofs, V.sub(0)), fem.dirichletbc(PETSc.ScalarType(0), down_dofs, V.sub(1))]

# %%
n = ufl.FacetNormal(mesh)
q_lim = float(2/np.sqrt(3)*np.log(Re/Ri)*sig0)

loading = fem.Constant(mesh, PETSc.ScalarType(0.0 * q_lim))

def F_ext(v):
    return -loading * ufl.inner(n, v)*ds(4)

def eps(v):
    e = ufl.sym(ufl.grad(v))
    return ufl.as_tensor([[e[0, 0], e[0, 1], 0],
                          [e[0, 1], e[1, 1], 0],
                          [0, 0, 0]])

def sigma(eps_el):
    return lmbda*ufl.tr(eps_el)*ufl.Identity(3) + 2*mu*eps_el

def as_3D_tensor(X):
    return ufl.as_tensor([[X[0], X[3], 0],
                          [X[3], X[1], 0],
                          [0, 0, X[2]]])

ppos = lambda x: (x + ufl.sqrt(x**2))/2.

def proj_sig(Du, old_sig, old_p):
    sig_n = as_3D_tensor(old_sig)
    sig_elas = sig_n + sigma(eps(Du))
    s = ufl.dev(sig_elas)
    sig_eq = ufl.sqrt(3/2.*ufl.inner(s, s))
    f_elas = sig_eq - sig0 - H*old_p
    # dp = ufl.conditional(f_elas > 0, f_elas/(3*mu+H), 0)
    dp = ppos(f_elas)/(3*mu+H)
    beta = ufl.conditional(f_elas > 0, 3*mu*dp/sig_eq, 0)
    new_sig = sig_elas-beta*s
    return ufl.as_vector([new_sig[0, 0], new_sig[1, 1], new_sig[2, 2], new_sig[0, 1]]), \
           dp

def deps_p(deps, old_sig, old_p):
    sig_n = as_3D_tensor(old_sig)
    sig_elas = sig_n + sigma(deps)
    s = ufl.dev(sig_elas)
    sig_eq = ufl.sqrt(3/2.*ufl.inner(s, s))
    f_elas = sig_eq - sig0 - H*old_p
    dp_sig_eq = ufl.conditional(f_elas > 0, f_elas/(3*mu+H)/sig_eq, 0) # sig_eq is equal to 0 on the first iteration
    # dp = ppos(f_elas)/(3*mu+H) # this approach doesn't work with ufl.derivate
    return 3./2. * dp_sig_eq * s

# %%
ds = ufl.Measure("ds", domain=mesh, subdomain_data=ft)
dx = ufl.Measure(
    "dx",
    domain=mesh,
    metadata={"quadrature_degree": deg_stress, "quadrature_scheme": "default"},
)

# %%
petsc_options_SNES = {
    "snes_type": "vinewtonrsls",
    "snes_linesearch_type": "basic",
    "ksp_type": "preonly",
    "pc_type": "lu",
    "pc_factor_mat_solver_type": "mumps",
    "snes_atol": 1.0e-08,
    "snes_rtol": 1.0e-09,
    "snes_stol": 0.0,
    "snes_max_it": 500,
    "snes_monitor": "",
}

petsc_options_SNESQN = {
    "snes_type": "qn",
    "snes_qn_type": "lbfgs", #lbfgs broyden, badbroyden
    "snes_qn_m": 100,
    "snes_qn_scale_type": "jacobian", #<diagonal,none,scalar,jacobian> 	
    "snes_qn_restart_type": "none", #<powell,periodic,none> 
    "pc_type": "cholesky", # cholesky >> hypre > gamg,sor ; asm, lu, gas - don't work
    "snes_linesearch_type": "basic",
    "ksp_type": "preonly",
    "pc_factor_mat_solver_type": "mumps",
    "snes_atol": 1.0e-08,
    "snes_rtol": 1.0e-08,
    "snes_stol": 0.0,
    "snes_max_it": 500,
    "snes_monitor": "",
    "snes_monitor_cancel": "",
}

sig_, dp_ = proj_sig(Du, sig_old, p)

def inside_Newton():
    fs.interpolate_quadrature(sig_, sig)
    fs.interpolate_quadrature(dp_, dp)

residual = ufl.inner(as_3D_tensor(sig_old) + sigma(eps(Du) - deps_p(eps(Du), sig_old, p)), eps(u_))*dx - F_ext(u_)
J = ufl.derivative(ufl.inner(sigma(eps(Du) - deps_p(eps(Du), sig_old, p)), eps(u_))*dx, Du, v)

my_problem = pf.SNESProblem(residual, Du, J, bcs, petsc_options=petsc_options_SNESQN, inside_Newton=inside_Newton)

# %%
# Defining a cell containing (Ri, 0) point, where we calculate a value of u
x_point = np.array([[Ri, 0, 0]])
cells, points_on_proc = fs.find_cell_by_point(mesh, x_point)

# %%
Nincr = 20
load_steps = np.linspace(0, 1.1, Nincr+1)[1:]**0.5
results = np.zeros((Nincr+1, 2))
load_steps = load_steps
# xdmf = io.XDMFFile(MPI.COMM_WORLD, "plasticity.xdmf", "w", encoding=io.XDMFFile.Encoding.HDF5)
# xdmf.write_mesh(mesh)

sig.vector.set(0.0)
sig_old.vector.set(0.0)
p.vector.set(0.0)
u.vector.set(0.0)

return_mapping_times = np.zeros((len(load_steps)))

start = time.time()

for (i, t) in enumerate(load_steps):
    return_mapping_times_tmp = []
    loading.value = t * q_lim

    Du.x.array[:] = 0

    my_problem.solve()

    nRes0 = my_problem.b.norm() # Which one? - ufl.sqrt(Res.dot(Res))
    nRes = nRes0

    if MPI.COMM_WORLD.rank == 0:
        print(f"\nnRes0 , {nRes0} \n Increment: {str(i+1)}, load = {t * q_lim}")
   
    # fs.interpolate_quadrature(sig_, sig)
    # fs.interpolate_quadrature(dp_, dp)
    p.vector.axpy(1, dp.vector)
    p.x.scatter_forward()
    u.vector.axpy(1, Du.vector) # u = u + 1*Du
    u.x.scatter_forward()
    
    sig_old.x.array[:] = sig.x.array

    # fs.project(p, p_avg)
    
    # xdmf.write_function(u, t)
    # xdmf.write_function(p_avg, t)

    if len(points_on_proc) > 0:
        results[i+1, :] = (u.eval(points_on_proc, cells)[0], t)

# xdmf.close()
# end = time.time()
# Out:
#   0 SNES Function norm 8.904703628988e-05
#   1 SNES Function norm 9.878568984112e-18
#
# nRes0 , 9.878568984111784e-18
#  Increment: 1, load = 0.0002537449238735671
#   0 SNES Function norm 3.688449012040e-05
#   1 SNES Function norm 4.175034146846e-18
#
# nRes0 , 4.175034146846265e-18
#  Increment: 2, load = 0.00035884951272532715
#   0 SNES Function norm 2.830246470722e-05
#   1 SNES Function norm 3.023853669230e-18
#
# nRes0 , 3.0238536692299764e-18
#  Increment: 3, load = 0.0004394991003117152
#   0 SNES Function norm 2.386008146226e-05
#   1 SNES Function norm 2.477319209764e-18
#
# nRes0 , 2.477319209763836e-18
#  Increment: 4, load = 0.0005074898477471342
#   0 SNES Function norm 2.102115375930e-05
#   1 SNES Function norm 2.281040467511e-18
#
# nRes0 , 2.2810404675112955e-18
#  Increment: 5, load = 0.0005673908987268053
#   0 SNES Function norm 1.900457567824e-05
#   1 SNES Function norm 1.989388944475e-18
#
# nRes0 , 1.9893889444745896e-18
#  Increment: 6, load = 0.000621545588311601
#   0 SNES Function norm 1.747651099306e-05
#   1 SNES Function norm 2.084734991415e-18
#
# nRes0 , 2.0847349914148114e-18
#  Increment: 7, load = 0.0006713459650144749
#   0 SNES Function norm 1.626673981019e-05
#   1 SNES Function norm 1.828656415392e-18
#
# nRes0 , 1.8286564153915423e-18
#  Increment: 8, load = 0.0007176990254506543
#   0 SNES Function norm 1.527805604909e-05
#   1 SNES Function norm 1.695726112595e-18
#
# nRes0 , 1.695726112594884e-18
#  Increment: 9, load = 0.0007612347716207013
#   0 SNES Function norm 1.445034469405e-05
#   1 SNES Function norm 1.686952796106e-18
#
# nRes0 , 1.6869527961060319e-18
#  Increment: 10, load = 0.0008024119041465073
#   0 SNES Function norm 1.374415450300e-05
#   1 SNES Function norm 1.464822103858e-18
#
# nRes0 , 1.4648221038576527e-18
#  Increment: 11, load = 0.0008415767049459163
#   0 SNES Function norm 1.313237416831e-05
#   1 SNES Function norm 1.554253774316e-05
#   2 SNES Function norm 5.505366403695e-06
#   3 SNES Function norm 7.668990968128e-07
#   4 SNES Function norm 5.662171644546e-07
#   5 SNES Function norm 1.016475257087e-07
#   6 SNES Function norm 3.974774345323e-08
#   7 SNES Function norm 1.988243970621e-08
#   8 SNES Function norm 9.325050524590e-09
#
# nRes0 , 9.325050524590378e-09
#  Increment: 12, load = 0.0008789982006234304
#   0 SNES Function norm 1.260079284524e-05
#   1 SNES Function norm 2.409185188808e-05
#   2 SNES Function norm 6.024057222188e-06
#   3 SNES Function norm 2.353616696565e-06
#   4 SNES Function norm 1.088009425766e-06
#   5 SNES Function norm 6.637555104012e-07
#   6 SNES Function norm 3.210277581313e-07
#   7 SNES Function norm 1.633685504041e-07
#   8 SNES Function norm 7.264850451675e-08
#   9 SNES Function norm 4.276581968772e-08
#  10 SNES Function norm 2.691173434914e-08
#  11 SNES Function norm 1.541857889635e-08
#  12 SNES Function norm 7.799303534106e-09
#
# nRes0 , 7.799303534106369e-09
#  Increment: 13, load = 0.0009148903339148527
#   0 SNES Function norm 1.211937688757e-05
#   1 SNES Function norm 9.558435334664e-06
#   2 SNES Function norm 3.556421044585e-06
#   3 SNES Function norm 1.313653597295e-06
#   4 SNES Function norm 5.599020733758e-07
#   5 SNES Function norm 3.414518648712e-07
#   6 SNES Function norm 1.683523949117e-07
#   7 SNES Function norm 1.118181685841e-07
#   8 SNES Function norm 7.005356531822e-08
#   9 SNES Function norm 3.785641003232e-08
#  10 SNES Function norm 1.374721085848e-08
#  11 SNES Function norm 4.555299860813e-09
#
# nRes0 , 4.555299860813457e-09
#  Increment: 14, load = 0.0009494265687679238
#   0 SNES Function norm 1.169327510589e-05
#   1 SNES Function norm 3.313793040673e-05
#   2 SNES Function norm 8.810994473427e-06
#   3 SNES Function norm 1.651047068567e-06
#   4 SNES Function norm 3.771805268793e-07
#   5 SNES Function norm 2.148414605980e-07
#   6 SNES Function norm 1.015517278464e-07
#   7 SNES Function norm 5.268353819693e-08
#   8 SNES Function norm 2.413891206388e-08
#   9 SNES Function norm 1.054904849826e-08
#  10 SNES Function norm 4.069590764631e-09
#
# nRes0 , 4.069590764631047e-09
#  Increment: 15, load = 0.0009827498643469941
#   0 SNES Function norm 1.131006587449e-05
#   1 SNES Function norm 3.377226812023e-05
#   2 SNES Function norm 1.184638652885e-05
#   3 SNES Function norm 2.901470379272e-06
#   4 SNES Function norm 1.679953871240e-06
#   5 SNES Function norm 1.320793639000e-06
#   6 SNES Function norm 5.538345473167e-07
#   7 SNES Function norm 2.634774521881e-07
#   8 SNES Function norm 1.793295486799e-07
#   9 SNES Function norm 1.028013222101e-07
#  10 SNES Function norm 6.197121558376e-08
#  11 SNES Function norm 3.656826444016e-08
#  12 SNES Function norm 1.804159661007e-08
#  13 SNES Function norm 9.591014743877e-09
#
# nRes0 , 9.591014743877295e-09
#  Increment: 16, load = 0.0010149796954942684
#   0 SNES Function norm 1.096246120484e-05
#   1 SNES Function norm 2.750311947651e-05
#   2 SNES Function norm 1.355810656136e-05
#   3 SNES Function norm 3.525884491337e-06
#   4 SNES Function norm 1.965098395586e-06
#   5 SNES Function norm 1.841876774353e-06
#   6 SNES Function norm 1.085890836636e-06
#   7 SNES Function norm 4.717045349959e-07
#   8 SNES Function norm 3.402752358607e-07
#   9 SNES Function norm 2.127130043238e-07
#  10 SNES Function norm 9.276154462759e-08
#  11 SNES Function norm 5.409706112422e-08
#  12 SNES Function norm 4.877660604594e-08
#  13 SNES Function norm 3.152336246571e-08
#  14 SNES Function norm 1.691284828310e-08
#  15 SNES Function norm 1.231252695320e-08
#  16 SNES Function norm 8.075272171610e-09
#
# nRes0 , 8.075272171610495e-09
#  Increment: 17, load = 0.0010462171230950295
#   0 SNES Function norm 1.064443046772e-05
#   1 SNES Function norm 4.522034758016e-05
#   2 SNES Function norm 3.085815536702e-05
#   3 SNES Function norm 9.770002966556e-06
#   4 SNES Function norm 3.639535648569e-06
#   5 SNES Function norm 2.789985695920e-06
#   6 SNES Function norm 1.355550279439e-06
#   7 SNES Function norm 6.631348524020e-07
#   8 SNES Function norm 6.043240487435e-07
#   9 SNES Function norm 4.802971344669e-07
#  10 SNES Function norm 3.438153618406e-07
#  11 SNES Function norm 2.475692335363e-07
#  12 SNES Function norm 1.969340665489e-07
#  13 SNES Function norm 1.430837116630e-07
#  14 SNES Function norm 9.983226767852e-08
#  15 SNES Function norm 7.415343550910e-08
#  16 SNES Function norm 5.847189197748e-08
#  17 SNES Function norm 4.781755560739e-08
#  18 SNES Function norm 3.845796163552e-08
#  19 SNES Function norm 3.027417733745e-08
#  20 SNES Function norm 2.194598295754e-08
#  21 SNES Function norm 1.455751945232e-08
#  22 SNES Function norm 1.115589151429e-08
#  23 SNES Function norm 1.065427541040e-08
#  24 SNES Function norm 9.171849070413e-09
#
# nRes0 , 9.17184907041329e-09
#  Increment: 18, load = 0.0010765485381759813
#   0 SNES Function norm 1.035252935263e-05
#   1 SNES Function norm 1.103897889342e-04
#   2 SNES Function norm 2.001792598889e-04
#   3 SNES Function norm 1.413896456518e-04
#   4 SNES Function norm 6.362738361559e-05
#   5 SNES Function norm 3.232762528646e-05
#   6 SNES Function norm 2.506919555122e-05
#   7 SNES Function norm 1.530321699693e-05
#   8 SNES Function norm 8.168856838044e-06
#   9 SNES Function norm 6.800538183127e-06
#  10 SNES Function norm 6.524465042628e-06
#  11 SNES Function norm 4.640679272884e-06
#  12 SNES Function norm 3.987380467516e-06
#  13 SNES Function norm 4.447887614080e-06
#  14 SNES Function norm 4.011054959641e-06
#  15 SNES Function norm 2.778597862533e-06
#  16 SNES Function norm 2.218200168689e-06
#  17 SNES Function norm 2.195559734504e-06
#  18 SNES Function norm 1.816552894323e-06
#  19 SNES Function norm 1.256955202408e-06
#  20 SNES Function norm 1.001857915483e-06
#  21 SNES Function norm 9.106287845356e-07
#  22 SNES Function norm 7.291689094636e-07
#  23 SNES Function norm 5.543025545418e-07
#  24 SNES Function norm 4.827948633735e-07
#  25 SNES Function norm 4.531921762687e-07
#  26 SNES Function norm 4.277117615268e-07
#  27 SNES Function norm 4.133838223348e-07
#  28 SNES Function norm 3.818654735615e-07
#  29 SNES Function norm 3.134129782817e-07
#  30 SNES Function norm 2.483980568043e-07
#  31 SNES Function norm 2.168068990521e-07
#  32 SNES Function norm 1.858425494936e-07
#  33 SNES Function norm 1.389230559795e-07
#  34 SNES Function norm 1.081675958838e-07
#  35 SNES Function norm 1.078240457832e-07
#  36 SNES Function norm 1.083556328725e-07
#  37 SNES Function norm 9.090297182255e-08
#  38 SNES Function norm 6.691366562868e-08
#  39 SNES Function norm 5.416490158512e-08
#  40 SNES Function norm 4.861098034387e-08
#  41 SNES Function norm 4.193319169120e-08
#  42 SNES Function norm 3.593982461767e-08
#  43 SNES Function norm 3.091207320595e-08
#  44 SNES Function norm 2.470159995132e-08
#  45 SNES Function norm 1.939626223333e-08
#  46 SNES Function norm 1.641648707090e-08
#  47 SNES Function norm 1.374240686200e-08
#  48 SNES Function norm 1.071786718399e-08
#  49 SNES Function norm 8.986461434258e-09
#
# nRes0 , 8.986461434258062e-09
#  Increment: 19, load = 0.0011060484806013002
#   0 SNES Function norm 1.008348665387e-05
#   1 SNES Function norm 5.473841904223e-05
#   2 SNES Function norm 2.680870698585e-05
#   3 SNES Function norm 9.342523605464e-06
#   4 SNES Function norm 3.422560670624e-06
#   5 SNES Function norm 2.440283681524e-06
#   6 SNES Function norm 2.040637520613e-06
#   7 SNES Function norm 1.335202774259e-06
#   8 SNES Function norm 9.860954395237e-07
#   9 SNES Function norm 8.621820285647e-07
#  10 SNES Function norm 7.409025243295e-07
#  11 SNES Function norm 5.637213775049e-07
#  12 SNES Function norm 4.237192565587e-07
#  13 SNES Function norm 3.391093398415e-07
#  14 SNES Function norm 2.693689640228e-07
#  15 SNES Function norm 2.085877436091e-07
#  16 SNES Function norm 1.603476792921e-07
#  17 SNES Function norm 1.246152590670e-07
#  18 SNES Function norm 9.572537889764e-08
#  19 SNES Function norm 7.143385120903e-08
#  20 SNES Function norm 5.352905800378e-08
#  21 SNES Function norm 4.368004452132e-08
#  22 SNES Function norm 3.878418570186e-08
#  23 SNES Function norm 3.527130941938e-08
#  24 SNES Function norm 2.955430397963e-08
#  25 SNES Function norm 2.389333052353e-08
#  26 SNES Function norm 2.053679368021e-08
#  27 SNES Function norm 1.779501302579e-08
#  28 SNES Function norm 1.422475352053e-08
#  29 SNES Function norm 1.117398835114e-08
#  30 SNES Function norm 9.640571511182e-09
#
# nRes0 , 9.640571511182184e-09
#  Increment: 20, load = 0.0011347817974536106

# %%
if len(points_on_proc) > 0:
    import matplotlib.pyplot as plt
    plt.plot(results[:, 0], results[:, 1], "-o")
    plt.xlabel("Displacement of inner boundary")
    plt.ylabel(r"Applied pressure $q/q_{lim}$")
    plt.savefig(f"displacement_rank{MPI.COMM_WORLD.rank:d}.png")
    plt.show()
