# %% [markdown]
# Implementation of 2D elasto-plastic problem using FEniCS-X. The code is based on a [legacy solution](https://comet-fenics.readthedocs.io/en/latest/demo/2D_plasticity/vonMises_plasticity.py.html) for FEniCS 2019.
#
# The program was tested for 0.3.1.0 version of Dolfinx.

# %%
import convex_return_mapping as crm # there is a conflict in the oder of imported modules
import meshio
import numpy as np

import ufl
from dolfinx import fem, io, common
from mpi4py import MPI
from petsc4py import PETSc

import sys
sys.path.append("../")
import fenicsx_support as fs
sys.path.append("../../optimisation")
import plasticity_framework as pf

# %%
if MPI.COMM_WORLD.rank == 0:

    #It works with the msh4 only!!
    msh = meshio.read("thick_cylinder_coarse.msh")

    # Create and save one file for the mesh, and one file for the facets 
    triangle_mesh = fs.create_mesh(msh, "triangle", prune_z=True)
    line_mesh = fs.create_mesh(msh, "line", prune_z=True)
    meshio.write("thick_cylinder.xdmf", triangle_mesh)
    meshio.write("mt.xdmf", line_mesh)
    print(msh)
# Out:
# <meshio mesh object>
#   Number of points: 50
#   Number of cells:
#     line: 2
#     line: 14
#     line: 2
#     line: 11
#     triangle: 69
#   Cell sets: gmsh:bounding_entities
#   Point data: gmsh:dim_tags
#   Cell data: gmsh:physical, gmsh:geometrical

# %%
with io.XDMFFile(MPI.COMM_WORLD, "thick_cylinder.xdmf", "r") as xdmf:
    mesh = xdmf.read_mesh(name="Grid")
    ct = xdmf.read_meshtags(mesh, name="Grid")

mesh.topology.create_connectivity(mesh.topology.dim, mesh.topology.dim - 1)

with io.XDMFFile(MPI.COMM_WORLD, "mt.xdmf", "r") as xdmf:
    ft = xdmf.read_meshtags(mesh, name="Grid")

# %%
# elastic parameters
sig0_dim = 70e3 #[Pa]
Ri_dim = 1.0 #[m]

E = 70e3 / sig0_dim #[-]
nu = 0.3 #[-]
lmbda = E*nu/(1+nu)/(1-2*nu)
mu = fem.Constant(mesh, PETSc.ScalarType(E/2./(1+nu)))

sig0 = 250 / sig0_dim #[-]
Et = E/100.  # tangent modulus
H = E*Et/(E-Et)  # hardening modulus

Re, Ri = 1.3, 1.   # external/internal radius

# %%
deg_u = 2
deg_stress = 2
V = fem.VectorFunctionSpace(mesh, ("CG", deg_u))
We = ufl.VectorElement("Quadrature", mesh.ufl_cell(), degree=deg_stress, dim=4, quad_scheme='default')
W0e = ufl.FiniteElement("Quadrature", mesh.ufl_cell(), degree=deg_stress, quad_scheme='default')
WTe = ufl.TensorElement("Quadrature", mesh.ufl_cell(), degree=deg_stress, shape=(4, 4), quad_scheme='default')

W = fem.FunctionSpace(mesh, We)
W0 = fem.FunctionSpace(mesh, W0e)
WT = fem.FunctionSpace(mesh, WTe)

# %%
sig = fem.Function(W)
sig_old = fem.Function(W)
p = fem.Function(W0, name="Cumulative_plastic_strain")
p_old = fem.Function(W0, name="Cumulative_plastic_strain")
u = fem.Function(V, name="Total_displacement")
du = fem.Function(V, name="Iteration_correction")
Du = fem.Function(V, name="Current_increment")
v = ufl.TrialFunction(V)
u_ = ufl.TestFunction(V)
C_tang = fem.Function(WT)

deps = fem.Function(W, name="deps")

P0 = fem.FunctionSpace(mesh, ("DG", 0))
p_avg = fem.Function(P0, name="Plastic_strain")

# %%
left_marker = 3
down_marker = 1
left_facets = ft.indices[ft.values == left_marker]
down_facets = ft.indices[ft.values == down_marker]
left_dofs = fem.locate_dofs_topological(V.sub(0), mesh.topology.dim-1, left_facets)
down_dofs = fem.locate_dofs_topological(V.sub(1), mesh.topology.dim-1, down_facets)

bcs = [fem.dirichletbc(PETSc.ScalarType(0), left_dofs, V.sub(0)), fem.dirichletbc(PETSc.ScalarType(0), down_dofs, V.sub(1))]

# %%
n = ufl.FacetNormal(mesh)
q_lim = float(2/np.sqrt(3)*np.log(Re/Ri)*sig0)
loading = fem.Constant(mesh, PETSc.ScalarType(0.0 * q_lim))

SQRT2 = np.sqrt(2.)

def F_ext(v):
    return -loading * ufl.inner(n, v)*ds(4)

def eps(v):
    e = ufl.sym(ufl.grad(v))
    return ufl.as_tensor([[e[0, 0], e[0, 1], 0],
                          [e[0, 1], e[1, 1], 0],
                          [0, 0, 0]])
def sigma(eps_el):
    return lmbda*ufl.tr(eps_el)*ufl.Identity(3) + 2*mu*eps_el
    
def eps_vec(v):
    e = ufl.sym(ufl.grad(v))
    return ufl.as_vector([e[0, 0], e[1, 1], 0, SQRT2 * e[0, 1]])

def as_3D_tensor(X):
    return ufl.as_tensor([[X[0], X[3] / SQRT2, 0],
                          [X[3] / SQRT2, X[1], 0],
                          [0, 0, X[2]]])

# %%
sigt = 250 / sig0_dim
sigc = 250 / sig0_dim

rankine = crm.Rankine(sigt, sigc, H)
material = crm.Material(crm.IsotropicElasticity(E, nu), rankine)

# %%
n_quadrature_points = len(C_tang.x.array.reshape((-1, 4, 4)))
for i in range(n_quadrature_points):
    C_tang.x.array.reshape((-1, 4, 4))[i,:,:] = material.C

N = patch_size = 3 # or batch, or group ?
N_patches = int(n_quadrature_points/patch_size)
residue_size = n_quadrature_points % patch_size

return_mapping = crm.ReturnMapping(material, patch_size)

p_values = p.x.array[:n_quadrature_points - residue_size].reshape((-1, patch_size))
p_old_values = p_old.x.array[:n_quadrature_points - residue_size].reshape((-1, patch_size))
deps_values = deps.x.array[:4*(n_quadrature_points - residue_size)].reshape((-1, patch_size, 4))
sig_values = sig.x.array[:4*(n_quadrature_points - residue_size)].reshape((-1, patch_size, 4))
sig_old_values = sig_old.x.array[:4*(n_quadrature_points - residue_size)].reshape((-1, patch_size, 4))
C_tang_values = C_tang.x.array[:4*4*(n_quadrature_points - residue_size)].reshape((-1, patch_size, 4, 4))

if residue_size != 0:
    return_mapping_residue = crm.ReturnMapping(material, residue_size)
    
    p_values_residue = p.x.array[n_quadrature_points - residue_size:].reshape((1, residue_size))
    p_old_values_residue = p_old.x.array[n_quadrature_points - residue_size:].reshape((1, residue_size))
    deps_values_residue = deps.x.array[4*(n_quadrature_points - residue_size):].reshape((1, residue_size, 4))
    sig_values_residue = sig.x.array[4*(n_quadrature_points - residue_size):].reshape((1, residue_size, 4))
    sig_old_values_residue = sig_old.x.array[4*(n_quadrature_points - residue_size):].reshape((1, residue_size, 4))
    C_tang_values_residue = C_tang.x.array[4*4*(n_quadrature_points - residue_size):].reshape((1, residue_size, 4, 4))

# %%
ds = ufl.Measure("ds", domain=mesh, subdomain_data=ft)
dx = ufl.Measure(
    "dx",
    domain=mesh,
    metadata={"quadrature_degree": deg_stress, "quadrature_scheme": "default"},
)

# %%
petsc_options_SNES = {
    "snes_type": "vinewtonrsls",
    "snes_linesearch_type": "basic",
    "ksp_type": "preonly",
    "pc_type": "lu",
    "pc_factor_mat_solver_type": "mumps",
    "snes_atol": 1.0e-08,
    "snes_rtol": 1.0e-08,
    "snes_stol": 0.0,
    "snes_max_it": 500,
    "snes_monitor": "",
}

petsc_options_SNESQN = {
    "snes_type": "qn",
    "snes_qn_type": "lbfgs", #lbfgs broyden, badbroyden
    "snes_qn_m": 100,
    "snes_qn_scale_type": "jacobian", #<diagonal,none,scalar,jacobian> 	
    "snes_qn_restart_type": "none", #<powell,periodic,none> 
    "pc_type": "cholesky", # cholesky >> hypre > gamg,sor ; asm, lu, gas - don't work
    "snes_linesearch_type": "basic",
    "ksp_type": "preonly",
    "pc_factor_mat_solver_type": "mumps",
    "snes_atol": 1.0e-08,
    "snes_rtol": 1.0e-08,
    "snes_stol": 0.0,
    "snes_max_it": 500,
    "snes_monitor": "",
    # "snes_monitor_cancel": "",
}

def inside_Newton():
    tol = 1e-13
    fs.interpolate_quadrature(eps_vec(Du), deps) # eps_xy * sqrt(2.)!

    for q in range(N_patches):
        return_mapping.deps.value[:] = deps_values[q,:].T
        return_mapping.sig_old.value[:] = sig_old_values[q,:].T
        return_mapping.p_old.value = p_old_values[q,:]
        
        return_mapping.solve(derivation=False, verbose=False, eps=tol, eps_abs=tol, eps_rel=tol)
        sig_values[q,:] = return_mapping.sig.value[:].T
        p_values[q,:] = return_mapping.p.value

    if residue_size != 0: #how to improve ?
        return_mapping_residue.deps.value[:] = deps_values_residue[0,:].T
        return_mapping_residue.sig_old.value[:] = sig_old_values_residue[0,:].T
        return_mapping_residue.p_old.value = p_old_values_residue[0,:]
        
        return_mapping_residue.solve(derivation=False, verbose=False, eps=tol, eps_abs=tol, eps_rel=tol)

        sig_values_residue[0,:] = return_mapping_residue.sig.value[:].T
        p_values_residue[0,:] = return_mapping_residue.p.value

residual = ufl.inner(as_3D_tensor(sig), eps(u_))*dx - F_ext(u_)
J = ufl.derivative(ufl.inner(sigma(eps(Du)), eps(u_))*dx, Du, v) #TODO: check J-formula!

snes_problem = pf.SNESProblem(residual, Du, J, bcs, petsc_options=petsc_options_SNESQN, inside_Newton=inside_Newton)

# %%
# Defining a cell containing (Ri, 0) point, where we calculate a value of u
x_point = np.array([[Ri, 0, 0]])
cells, points_on_proc = fs.find_cell_by_point(mesh, x_point)

# %%
Nitermax, tol = 200, 1e-7  # parameters of the Newton-Raphson procedure
Nincr = 20
load_steps = np.linspace(0, 1.1, Nincr+1)[1:]**0.5
results = np.zeros((Nincr+1, 2))
load_steps = load_steps
# xdmf = io.XDMFFile(MPI.COMM_WORLD, "plasticity.xdmf", "w", encoding=io.XDMFFile.Encoding.HDF5)
# xdmf.write_mesh(mesh)

sig.vector.set(0.0)
sig_old.vector.set(0.0)
p.vector.set(0.0)
p_old.vector.set(0.0)
u.vector.set(0.0)
du.vector.set(0.0)

n_quadrature_points = len(C_tang.x.array.reshape((-1, 4, 4)))
for i in range(n_quadrature_points):
    C_tang.x.array.reshape((-1, 4, 4))[i,:,:] = material.C

with common.Timer() as timer: 
    for (i, t) in enumerate(load_steps):
        loading.value = t * q_lim

        Du.x.array[:] = 0

        if MPI.COMM_WORLD.rank == 0:
            print(f"\n Increment: {str(i+1)}, load = {t * q_lim}")
        niter = 0

        snes_problem.solve()

        u.vector.axpy(1, Du.vector) # u = u + 1*Du
        u.x.scatter_forward()

        p_old.x.array[:] = p.x.array       
        sig_old.x.array[:] = sig.x.array

        # fs.project(p, p_avg)
        
        # xdmf.write_function(u, t)
        # xdmf.write_function(p_avg, t)

        if len(points_on_proc) > 0:
            results[i+1, :] = (u.eval(points_on_proc, cells)[0], t)
    
    # xdmf.close()

    print(f'\nrank#{MPI.COMM_WORLD.rank}: Time = {timer.elapsed()[0]:.3f} (s)')
# Out:
#  Increment: 1, load = 0.0002537449238735671
#   0 SNES Function norm 8.904703628988e-05
#   1 SNES Function norm 3.209910450684e-15
#
#  Increment: 2, load = 0.00035884951272532715
#   0 SNES Function norm 3.688449012149e-05
#   1 SNES Function norm 3.751179722752e-16
#
#  Increment: 3, load = 0.0004394991003117152
#   0 SNES Function norm 2.830246470746e-05
#   1 SNES Function norm 7.766421263789e-17
#
#  Increment: 4, load = 0.0005074898477471342
#   0 SNES Function norm 2.386008146245e-05
#   1 SNES Function norm 2.378184011563e-16
#
#  Increment: 5, load = 0.0005673908987268053
#   0 SNES Function norm 2.102115375952e-05
#   1 SNES Function norm 2.030323492628e-16
#
#  Increment: 6, load = 0.000621545588311601
#   0 SNES Function norm 1.900457567847e-05
#   1 SNES Function norm 1.033228146689e-16
#
#  Increment: 7, load = 0.0006713459650144749
#   0 SNES Function norm 1.747651099331e-05
#   1 SNES Function norm 9.993694026006e-17
#
#  Increment: 8, load = 0.0007176990254506543
#   0 SNES Function norm 1.626673981046e-05
#   1 SNES Function norm 1.064999272572e-16
#
#  Increment: 9, load = 0.0007612347716207013
#   0 SNES Function norm 1.527805604937e-05
#   1 SNES Function norm 1.885100584038e-16
#
#  Increment: 10, load = 0.0008024119041465073
#   0 SNES Function norm 1.445034469435e-05
#   1 SNES Function norm 2.490740606886e-15
#
#  Increment: 11, load = 0.0008415767049459163
#   0 SNES Function norm 1.374415450464e-05
#   1 SNES Function norm 3.495882733702e-15
#
#  Increment: 12, load = 0.0008789982006234304
#   0 SNES Function norm 1.313237416761e-05
#   1 SNES Function norm 3.574109302206e-16
#
#  Increment: 13, load = 0.0009148903339148527
#   0 SNES Function norm 1.259567303611e-05
#   1 SNES Function norm 5.651737403392e-16
#
#  Increment: 14, load = 0.0009494265687679238
#   0 SNES Function norm 1.211984583301e-05
#   1 SNES Function norm 1.058950694963e-05
#   2 SNES Function norm 2.982692229385e-06
#   3 SNES Function norm 5.924670867263e-07
#   4 SNES Function norm 5.385063359208e-07
#   5 SNES Function norm 2.698927427869e-07
#   6 SNES Function norm 1.162015024586e-07
#   7 SNES Function norm 7.647932708291e-08
#   8 SNES Function norm 6.727075535930e-08
#   9 SNES Function norm 3.800890677122e-08
#  10 SNES Function norm 2.108497925331e-08
#  11 SNES Function norm 1.700396075645e-08
#  12 SNES Function norm 1.418002210844e-08
#  13 SNES Function norm 9.828024258053e-09
#
#  Increment: 15, load = 0.0009827498643469941
#   0 SNES Function norm 1.169543579724e-05
#   1 SNES Function norm 1.994634618556e-05
#   2 SNES Function norm 7.379471386495e-06
#   3 SNES Function norm 2.378492098304e-06
#   4 SNES Function norm 1.475541092796e-06
#   5 SNES Function norm 9.201868163011e-07
#   6 SNES Function norm 6.949373092190e-07
#   7 SNES Function norm 3.414964963584e-07
#   8 SNES Function norm 1.724825363832e-07
#   9 SNES Function norm 1.547223162471e-07
#  10 SNES Function norm 1.558645806038e-07
#  11 SNES Function norm 9.369762408034e-08
#  12 SNES Function norm 3.368064706646e-08
#  13 SNES Function norm 2.263943972185e-08
#  14 SNES Function norm 2.494444955980e-08
#  15 SNES Function norm 2.254315629292e-08
#  16 SNES Function norm 1.321894146889e-08
#  17 SNES Function norm 7.284845552670e-09
#
#  Increment: 16, load = 0.0010149796954942684
#   0 SNES Function norm 1.131105762154e-05
#   1 SNES Function norm 1.667246822756e-05
#   2 SNES Function norm 5.843025408596e-06
#   3 SNES Function norm 2.173937578561e-06
#   4 SNES Function norm 1.807930394012e-06
#   5 SNES Function norm 9.471538398049e-07
#   6 SNES Function norm 5.350651018170e-07
#   7 SNES Function norm 2.383978918779e-07
#   8 SNES Function norm 1.785247711483e-07
#   9 SNES Function norm 1.428399671601e-07
#  10 SNES Function norm 9.808609269158e-08
#  11 SNES Function norm 5.710617190288e-08
#  12 SNES Function norm 4.464325164017e-08
#  13 SNES Function norm 3.804324436408e-08
#  14 SNES Function norm 2.614200750185e-08
#  15 SNES Function norm 1.732688029783e-08
#  16 SNES Function norm 1.638590309401e-08
#  17 SNES Function norm 1.630846872647e-08
#  18 SNES Function norm 1.084149123447e-08
#  19 SNES Function norm 4.808514182179e-09
#
#  Increment: 17, load = 0.0010462171230950295
#   0 SNES Function norm 1.096201997661e-05
#   1 SNES Function norm 2.362118623146e-05
#   2 SNES Function norm 9.016041598911e-06
#   3 SNES Function norm 2.630438831871e-06
#   4 SNES Function norm 1.437081942946e-06
#   5 SNES Function norm 1.096271991755e-06
#   6 SNES Function norm 1.071424749358e-06
#   7 SNES Function norm 8.313433375008e-07
#   8 SNES Function norm 6.246401252154e-07
#   9 SNES Function norm 3.874350442403e-07
#  10 SNES Function norm 2.287702272682e-07
#  11 SNES Function norm 1.304801391024e-07
#  12 SNES Function norm 1.069456688696e-07
#  13 SNES Function norm 1.091547104218e-07
#  14 SNES Function norm 1.076970630899e-07
#  15 SNES Function norm 8.208982797290e-08
#  16 SNES Function norm 4.990655168674e-08
#  17 SNES Function norm 3.350683049795e-08
#  18 SNES Function norm 2.789450630082e-08
#  19 SNES Function norm 2.520240056308e-08
#  20 SNES Function norm 2.099359865054e-08
#  21 SNES Function norm 1.609376308572e-08
#  22 SNES Function norm 1.305723563224e-08
#  23 SNES Function norm 1.093313508271e-08
#  24 SNES Function norm 7.997295892010e-09
#
#  Increment: 18, load = 0.0010765485381759813
#   0 SNES Function norm 1.064407167083e-05
#   1 SNES Function norm 3.210431088672e-05
#   2 SNES Function norm 1.896849538391e-05
#   3 SNES Function norm 1.090024236180e-05
#   4 SNES Function norm 4.922981006701e-06
#   5 SNES Function norm 5.410467352583e-06
#   6 SNES Function norm 1.334474809506e-05
#   7 SNES Function norm 1.010195165645e-05
#   8 SNES Function norm 3.769405080148e-06
#   9 SNES Function norm 2.532692617043e-06
#  10 SNES Function norm 2.289332678972e-06
#  11 SNES Function norm 1.397497723541e-06
#  12 SNES Function norm 6.799318878534e-07
#  13 SNES Function norm 6.920282553383e-07
#  14 SNES Function norm 8.144599126169e-07
#  15 SNES Function norm 7.382711775049e-07
#  16 SNES Function norm 6.183482856674e-07
#  17 SNES Function norm 6.829055994561e-07
#  18 SNES Function norm 7.902684802122e-07
#  19 SNES Function norm 7.444014830282e-07
#  20 SNES Function norm 6.105710405534e-07
#  21 SNES Function norm 5.822592308834e-07
#  22 SNES Function norm 6.019825977363e-07
#  23 SNES Function norm 4.984471315454e-07
#  24 SNES Function norm 3.139368666641e-07
#  25 SNES Function norm 2.168558446744e-07
#  26 SNES Function norm 1.811554954980e-07
#  27 SNES Function norm 1.417727630115e-07
#  28 SNES Function norm 1.215570473876e-07
#  29 SNES Function norm 1.361270986246e-07
#  30 SNES Function norm 1.446976844139e-07
#  31 SNES Function norm 1.237577193864e-07
#  32 SNES Function norm 1.006026035313e-07
#  33 SNES Function norm 1.000690019762e-07
#  34 SNES Function norm 1.038550699045e-07
#  35 SNES Function norm 9.663968109132e-08
#  36 SNES Function norm 8.738613094344e-08
#  37 SNES Function norm 8.701180668131e-08
#  38 SNES Function norm 8.485157613995e-08
#  39 SNES Function norm 7.239084134116e-08
#  40 SNES Function norm 5.818003386553e-08
#  41 SNES Function norm 5.000478396853e-08
#  42 SNES Function norm 4.153384624222e-08
#  43 SNES Function norm 3.176599627789e-08
#  44 SNES Function norm 2.785622288879e-08
#  45 SNES Function norm 2.965876786807e-08
#  46 SNES Function norm 3.009574741068e-08
#  47 SNES Function norm 2.584827616656e-08
#  48 SNES Function norm 2.011456754394e-08
#  49 SNES Function norm 1.687434366977e-08
#  50 SNES Function norm 1.465293259347e-08
#  51 SNES Function norm 1.274444724004e-08
#  52 SNES Function norm 1.242768290221e-08
#  53 SNES Function norm 1.311056779661e-08
#  54 SNES Function norm 1.256989242314e-08
#  55 SNES Function norm 1.088183767658e-08
#  56 SNES Function norm 9.335170843859e-09
#
#  Increment: 19, load = 0.0011060484806013002
#   0 SNES Function norm 1.035256599800e-05
#   1 SNES Function norm 7.164336711364e-05
#   2 SNES Function norm 8.110343278543e-05
#   3 SNES Function norm 3.462823585593e-05
#   4 SNES Function norm 1.571851164426e-05
#   5 SNES Function norm 8.675131397347e-06
#   6 SNES Function norm 9.250955772973e-06
#   7 SNES Function norm 8.491783123234e-06
#   8 SNES Function norm 5.803196356202e-06
#   9 SNES Function norm 4.444314210532e-06
#  10 SNES Function norm 4.493366096550e-06
#  11 SNES Function norm 3.829728459996e-06
#  12 SNES Function norm 2.933874419853e-06
#  13 SNES Function norm 2.830233378853e-06
#  14 SNES Function norm 2.856920205654e-06
#  15 SNES Function norm 2.277601364829e-06
#  16 SNES Function norm 1.612895089138e-06
#  17 SNES Function norm 1.429906032893e-06
#  18 SNES Function norm 1.446669348525e-06
#  19 SNES Function norm 1.251489078259e-06
#  20 SNES Function norm 1.025996784455e-06
#  21 SNES Function norm 1.003527916149e-06
#  22 SNES Function norm 1.006120979798e-06
#  23 SNES Function norm 8.770777668635e-07
#  24 SNES Function norm 7.034842499908e-07
#  25 SNES Function norm 6.508812473402e-07
#  26 SNES Function norm 6.129857545819e-07
#  27 SNES Function norm 4.958051633132e-07
#  28 SNES Function norm 3.620023747783e-07
#  29 SNES Function norm 3.047494129520e-07
#  30 SNES Function norm 2.882730721499e-07
#  31 SNES Function norm 2.697207409623e-07
#  32 SNES Function norm 2.634973277477e-07
#  33 SNES Function norm 2.681676279881e-07
#  34 SNES Function norm 2.532676334134e-07
#  35 SNES Function norm 2.121307642939e-07
#  36 SNES Function norm 1.796657690007e-07
#  37 SNES Function norm 1.764841308700e-07
#  38 SNES Function norm 1.759347960130e-07
#  39 SNES Function norm 1.627582516261e-07
#  40 SNES Function norm 1.466902037529e-07
#  41 SNES Function norm 1.337827570411e-07
#  42 SNES Function norm 1.171480248678e-07
#  43 SNES Function norm 9.884181809086e-08
#  44 SNES Function norm 8.844708960435e-08
#  45 SNES Function norm 8.259317149268e-08
#  46 SNES Function norm 7.262758803900e-08
#  47 SNES Function norm 5.800035974421e-08
#  48 SNES Function norm 4.623400918492e-08
#  49 SNES Function norm 4.025058141764e-08
#  50 SNES Function norm 3.722675473113e-08
#  51 SNES Function norm 3.643579013787e-08
#  52 SNES Function norm 3.672108758627e-08
#  53 SNES Function norm 3.422677221061e-08
#  54 SNES Function norm 2.898109282633e-08
#  55 SNES Function norm 2.491236935541e-08
#  56 SNES Function norm 2.351138588599e-08
#  57 SNES Function norm 2.237282321608e-08
#  58 SNES Function norm 1.944586985470e-08
#  59 SNES Function norm 1.638979200526e-08
#  60 SNES Function norm 1.436923305256e-08
#  61 SNES Function norm 1.258547688925e-08
#  62 SNES Function norm 1.065282854060e-08
#  63 SNES Function norm 9.476888070253e-09
#
#  Increment: 20, load = 0.0011347817974536106
#   0 SNES Function norm 1.008320080129e-05
#   1 SNES Function norm 5.379182662724e-07
#   2 SNES Function norm 2.112423687929e-07
#   3 SNES Function norm 1.292715022069e-07
#   4 SNES Function norm 6.692216703454e-08
#   5 SNES Function norm 5.932044435999e-08
#   6 SNES Function norm 4.539007109677e-08
#   7 SNES Function norm 3.993774891013e-08
#   8 SNES Function norm 3.263152069065e-08
#   9 SNES Function norm 3.017959814128e-08
#  10 SNES Function norm 3.077538801731e-08
#  11 SNES Function norm 3.225030990029e-08
#  12 SNES Function norm 3.060591100959e-08
#  13 SNES Function norm 2.501386695560e-08
#  14 SNES Function norm 1.959531475802e-08
#  15 SNES Function norm 1.540773063735e-08
#  16 SNES Function norm 1.142879813094e-08
#  17 SNES Function norm 8.864595667029e-09
#
# rank#0: Time = 109.224 (s)

# %%
if len(points_on_proc) > 0:
    import matplotlib.pyplot as plt
    plt.plot(results[:, 0], results[:, 1], "-o")
    plt.xlabel("Displacement of inner boundary")
    plt.ylabel(r"Applied pressure $q/q_{lim}$")
    plt.savefig(f"displacement_rank{MPI.COMM_WORLD.rank:d}.png")
    plt.show()
